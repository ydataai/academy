# %% [markdown]
# <span style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">An Exception was encountered at '<a href="#papermill-error-cell">In [2]</a>'.</span>

# %% [markdown]
# # Setup Experiments
#
# ## Install required packages

# %% [markdown]
# ## Create asset folders
#
# Let's create all the folders that are needed to store the intermediate results, raw results and analysis reports.

# %%
from common.config import create_experiment_folders

# %% [markdown]
# <span id="papermill-error-cell" style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">Execution using papermill encountered an exception here and stopped:</span>

# %%
create_experiment_folders()
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In [2], line 1
# ----> 1 create_experiment_folders()
#
# File /mnt/laboratory/ec9ddafc-a127-4444-af4a-b76735f9e4c3/common/config.py:27, in create_experiment_folders(folders)
#      25 for folder in folders:
#      26     if not os.path.exists(folder):
# ---> 27         os.makedirs(folder)
#
# File /opt/conda/lib/python3.8/os.py:213, in makedirs(name, mode, exist_ok)
#     211 if head and tail and not path.exists(head):
#     212     try:
# --> 213         makedirs(head, exist_ok=exist_ok)
#     214     except FileExistsError:
#     215         # Defeats race condition when another thread created the path
#     216         pass
#
# File /opt/conda/lib/python3.8/os.py:213, in makedirs(name, mode, exist_ok)
#     211 if head and tail and not path.exists(head):
#     212     try:
# --> 213         makedirs(head, exist_ok=exist_ok)
#     214     except FileExistsError:
#     215         # Defeats race condition when another thread created the path
#     216         pass
#
# File /opt/conda/lib/python3.8/os.py:213, in makedirs(name, mode, exist_ok)
#     211 if head and tail and not path.exists(head):
#     212     try:
# --> 213         makedirs(head, exist_ok=exist_ok)
#     214     except FileExistsError:
#     215         # Defeats race condition when another thread created the path
#     216         pass
#
# File /opt/conda/lib/python3.8/os.py:223, in makedirs(name, mode, exist_ok)
#     221         return
#     222 try:
# --> 223     mkdir(name, mode)
#     224 except OSError:
#     225     # Cannot rely on checking for EEXIST, since the operating system
#     226     # could give priority to other errors like EACCES or EROFS
#     227     if not exist_ok or not path.isdir(name):
#
# PermissionError: [Errno 13] Permission denied: '/mount'
