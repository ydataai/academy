# %% [markdown]
# # Data Preprocessing
# This notebooks loads and preprocesses the raw data for missing values imputation.

# %% [markdown]
# ## 0 - Setup

# %% [markdown]
# ### 0.1 - Imports
# Load the necessary dependencies.

# %%
from ydata.connectors import GCSConnector, LocalConnector
from ydata.utils.formats import read_json

# %% [markdown]
# ## 0.2 - Auxiliary Functions
# The auxiliary functions are custom-designed utilities developed for the REE use case.

# %%
from ydata.dataset import Dataset
from preprocess import preprocess_data

# %% [markdown]
# ## 1 - Load Data
# First extraction: 26 November 2020 - 15 July 2021
#
# Second extraction: 15 July 2021 - 29 September 2021

# %%
# Load the credentials
credentials = read_json('gcs_credentials.json')

# Create the connector for Google Cloud Storage
connector = GCSConnector('ydatasynthetic', gcs_credentials=credentials)

# Read the first extraction data 26 Nov 2020 to 15 Jul 2021
data = connector.read_file('gs://pipelines_artifacts/wind_measurements_pipeline/data/ethiopia_wind_lot_nan.csv')
# Out:
# INFO: 2022-02-18 11:50:56,676 [CONNECTOR] - Init data types inference.
# INFO: 2022-02-18 11:51:03,268 [CONNECTOR] - Data types infered.

# %% [markdown]
# ## 2 - Data Processing
#
# Train: 26 November 2021 - 31 August 2021
#
# Holdout: 1 September 2021 - 29 September 2021
#
# Steps:
#   1. Select the relevant columns
#   2. Convert to Pandas DataFrame
#   3. Cast to the correct data types
#   4. Join the readings from both extractions into a single table
#   5. Split into train and holdout

# %%
train, holdout = preprocess_data(data)

# %% [markdown]
# ## 3 - Store Data
# After data is preprocessed, store locally or to cloud storage.

# %%
local_connector = LocalConnector()

# Store the train
local_connector.write_file(data=train.reset_index(), path='train_allmeters.csv', index=True)

# Store the holdout
local_connector.write_file(data=holdout.reset_index(), path='holdout_allmeters.csv', index=True)
# Out:
# ERROR: 2022-02-18 12:07:27,840 Exception in callback None()
# handle: <Handle cancelled>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1391, in _do_ssl_handshake
#     self.socket.do_handshake()
#   File "/opt/conda/lib/python3.7/ssl.py", line 1139, in do_handshake
#     self._sslobj.do_handshake()
# ssl.SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate (_ssl.c:1091)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 696, in _handle_events
#     self._handle_read()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1478, in _handle_read
#     self._do_ssl_handshake()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1409, in _do_ssl_handshake
#     return self.close(exc_info=err)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 189, in _handle_events
#     handler_func(fileobj, events)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 732, in _handle_events
#     self.close(exc_info=e)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
# ERROR: 2022-02-18 12:07:27,843 Exception in callback None()
# handle: <Handle cancelled>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1391, in _do_ssl_handshake
#     self.socket.do_handshake()
#   File "/opt/conda/lib/python3.7/ssl.py", line 1139, in do_handshake
#     self._sslobj.do_handshake()
# ssl.SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate (_ssl.c:1091)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 696, in _handle_events
#     self._handle_read()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1478, in _handle_read
#     self._do_ssl_handshake()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1409, in _do_ssl_handshake
#     return self.close(exc_info=err)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 189, in _handle_events
#     handler_func(fileobj, events)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 732, in _handle_events
#     self.close(exc_info=e)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
# ERROR: 2022-02-18 12:07:30,699 Exception in callback None()
# handle: <Handle cancelled>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1391, in _do_ssl_handshake
#     self.socket.do_handshake()
#   File "/opt/conda/lib/python3.7/ssl.py", line 1139, in do_handshake
#     self._sslobj.do_handshake()
# ssl.SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate (_ssl.c:1091)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 696, in _handle_events
#     self._handle_read()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1478, in _handle_read
#     self._do_ssl_handshake()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1409, in _do_ssl_handshake
#     return self.close(exc_info=err)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 189, in _handle_events
#     handler_func(fileobj, events)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 732, in _handle_events
#     self.close(exc_info=e)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
# ERROR: 2022-02-18 12:07:31,215 Exception in callback None()
# handle: <Handle cancelled>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1391, in _do_ssl_handshake
#     self.socket.do_handshake()
#   File "/opt/conda/lib/python3.7/ssl.py", line 1139, in do_handshake
#     self._sslobj.do_handshake()
# ssl.SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate (_ssl.c:1091)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 696, in _handle_events
#     self._handle_read()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1478, in _handle_read
#     self._do_ssl_handshake()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1409, in _do_ssl_handshake
#     return self.close(exc_info=err)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 189, in _handle_events
#     handler_func(fileobj, events)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 732, in _handle_events
#     self.close(exc_info=e)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
# ERROR: 2022-02-18 12:07:31,533 Exception in callback None()
# handle: <Handle cancelled>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1391, in _do_ssl_handshake
#     self.socket.do_handshake()
#   File "/opt/conda/lib/python3.7/ssl.py", line 1139, in do_handshake
#     self._sslobj.do_handshake()
# ssl.SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate (_ssl.c:1091)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 696, in _handle_events
#     self._handle_read()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1478, in _handle_read
#     self._do_ssl_handshake()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1409, in _do_ssl_handshake
#     return self.close(exc_info=err)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 189, in _handle_events
#     handler_func(fileobj, events)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 732, in _handle_events
#     self.close(exc_info=e)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
# ERROR: 2022-02-18 12:07:31,837 Exception in callback None()
# handle: <Handle cancelled>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1391, in _do_ssl_handshake
#     self.socket.do_handshake()
#   File "/opt/conda/lib/python3.7/ssl.py", line 1139, in do_handshake
#     self._sslobj.do_handshake()
# ssl.SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate (_ssl.c:1091)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 696, in _handle_events
#     self._handle_read()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1478, in _handle_read
#     self._do_ssl_handshake()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1409, in _do_ssl_handshake
#     return self.close(exc_info=err)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 189, in _handle_events
#     handler_func(fileobj, events)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 732, in _handle_events
#     self.close(exc_info=e)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
# ERROR: 2022-02-18 12:07:31,872 Exception in callback None()
# handle: <Handle cancelled>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1391, in _do_ssl_handshake
#     self.socket.do_handshake()
#   File "/opt/conda/lib/python3.7/ssl.py", line 1139, in do_handshake
#     self._sslobj.do_handshake()
# ssl.SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate (_ssl.c:1091)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 696, in _handle_events
#     self._handle_read()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1478, in _handle_read
#     self._do_ssl_handshake()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1409, in _do_ssl_handshake
#     return self.close(exc_info=err)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 189, in _handle_events
#     handler_func(fileobj, events)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 732, in _handle_events
#     self.close(exc_info=e)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
# ERROR: 2022-02-18 12:07:31,911 Exception in callback None()
# handle: <Handle cancelled>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1391, in _do_ssl_handshake
#     self.socket.do_handshake()
#   File "/opt/conda/lib/python3.7/ssl.py", line 1139, in do_handshake
#     self._sslobj.do_handshake()
# ssl.SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate (_ssl.c:1091)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 696, in _handle_events
#     self._handle_read()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1478, in _handle_read
#     self._do_ssl_handshake()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1409, in _do_ssl_handshake
#     return self.close(exc_info=err)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 189, in _handle_events
#     handler_func(fileobj, events)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 732, in _handle_events
#     self.close(exc_info=e)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
# ERROR: 2022-02-18 12:07:31,945 Exception in callback None()
# handle: <Handle cancelled>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1391, in _do_ssl_handshake
#     self.socket.do_handshake()
#   File "/opt/conda/lib/python3.7/ssl.py", line 1139, in do_handshake
#     self._sslobj.do_handshake()
# ssl.SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate (_ssl.c:1091)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 696, in _handle_events
#     self._handle_read()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1478, in _handle_read
#     self._do_ssl_handshake()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1409, in _do_ssl_handshake
#     return self.close(exc_info=err)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 189, in _handle_events
#     handler_func(fileobj, events)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 732, in _handle_events
#     self.close(exc_info=e)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
# ERROR: 2022-02-18 12:07:32,169 Exception in callback None()
# handle: <Handle cancelled>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1391, in _do_ssl_handshake
#     self.socket.do_handshake()
#   File "/opt/conda/lib/python3.7/ssl.py", line 1139, in do_handshake
#     self._sslobj.do_handshake()
# ssl.SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate (_ssl.c:1091)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 696, in _handle_events
#     self._handle_read()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1478, in _handle_read
#     self._do_ssl_handshake()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1409, in _do_ssl_handshake
#     return self.close(exc_info=err)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 189, in _handle_events
#     handler_func(fileobj, events)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 732, in _handle_events
#     self.close(exc_info=e)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
# ERROR: 2022-02-18 12:07:32,207 Exception in callback None()
# handle: <Handle cancelled>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1391, in _do_ssl_handshake
#     self.socket.do_handshake()
#   File "/opt/conda/lib/python3.7/ssl.py", line 1139, in do_handshake
#     self._sslobj.do_handshake()
# ssl.SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate (_ssl.c:1091)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 696, in _handle_events
#     self._handle_read()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1478, in _handle_read
#     self._do_ssl_handshake()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1409, in _do_ssl_handshake
#     return self.close(exc_info=err)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 189, in _handle_events
#     handler_func(fileobj, events)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 732, in _handle_events
#     self.close(exc_info=e)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
# ERROR: 2022-02-18 12:07:32,234 Exception in callback None()
# handle: <Handle cancelled>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1391, in _do_ssl_handshake
#     self.socket.do_handshake()
#   File "/opt/conda/lib/python3.7/ssl.py", line 1139, in do_handshake
#     self._sslobj.do_handshake()
# ssl.SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate (_ssl.c:1091)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 696, in _handle_events
#     self._handle_read()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1478, in _handle_read
#     self._do_ssl_handshake()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1409, in _do_ssl_handshake
#     return self.close(exc_info=err)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 189, in _handle_events
#     handler_func(fileobj, events)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 732, in _handle_events
#     self.close(exc_info=e)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
# ERROR: 2022-02-18 12:07:32,257 Exception in callback None()
# handle: <Handle cancelled>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1391, in _do_ssl_handshake
#     self.socket.do_handshake()
#   File "/opt/conda/lib/python3.7/ssl.py", line 1139, in do_handshake
#     self._sslobj.do_handshake()
# ssl.SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate (_ssl.c:1091)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 696, in _handle_events
#     self._handle_read()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1478, in _handle_read
#     self._do_ssl_handshake()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1409, in _do_ssl_handshake
#     return self.close(exc_info=err)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 189, in _handle_events
#     handler_func(fileobj, events)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 732, in _handle_events
#     self.close(exc_info=e)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
# ERROR: 2022-02-18 12:07:32,269 Exception in callback None()
# handle: <Handle cancelled>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1391, in _do_ssl_handshake
#     self.socket.do_handshake()
#   File "/opt/conda/lib/python3.7/ssl.py", line 1139, in do_handshake
#     self._sslobj.do_handshake()
# ssl.SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate (_ssl.c:1091)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 696, in _handle_events
#     self._handle_read()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1478, in _handle_read
#     self._do_ssl_handshake()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1409, in _do_ssl_handshake
#     return self.close(exc_info=err)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 189, in _handle_events
#     handler_func(fileobj, events)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 732, in _handle_events
#     self.close(exc_info=e)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
# ERROR: 2022-02-18 12:07:32,321 Exception in callback None()
# handle: <Handle cancelled>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1391, in _do_ssl_handshake
#     self.socket.do_handshake()
#   File "/opt/conda/lib/python3.7/ssl.py", line 1139, in do_handshake
#     self._sslobj.do_handshake()
# ssl.SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate (_ssl.c:1091)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 696, in _handle_events
#     self._handle_read()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1478, in _handle_read
#     self._do_ssl_handshake()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1409, in _do_ssl_handshake
#     return self.close(exc_info=err)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 189, in _handle_events
#     handler_func(fileobj, events)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 732, in _handle_events
#     self.close(exc_info=e)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
# ERROR: 2022-02-18 12:07:32,330 Exception in callback None()
# handle: <Handle cancelled>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1391, in _do_ssl_handshake
#     self.socket.do_handshake()
#   File "/opt/conda/lib/python3.7/ssl.py", line 1139, in do_handshake
#     self._sslobj.do_handshake()
# ssl.SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate (_ssl.c:1091)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 696, in _handle_events
#     self._handle_read()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1478, in _handle_read
#     self._do_ssl_handshake()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1409, in _do_ssl_handshake
#     return self.close(exc_info=err)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 189, in _handle_events
#     handler_func(fileobj, events)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 732, in _handle_events
#     self.close(exc_info=e)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
# ERROR: 2022-02-18 12:07:32,362 Exception in callback None()
# handle: <Handle cancelled>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1391, in _do_ssl_handshake
#     self.socket.do_handshake()
#   File "/opt/conda/lib/python3.7/ssl.py", line 1139, in do_handshake
#     self._sslobj.do_handshake()
# ssl.SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate (_ssl.c:1091)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 696, in _handle_events
#     self._handle_read()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1478, in _handle_read
#     self._do_ssl_handshake()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1409, in _do_ssl_handshake
#     return self.close(exc_info=err)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 189, in _handle_events
#     handler_func(fileobj, events)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 732, in _handle_events
#     self.close(exc_info=e)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
# ERROR: 2022-02-18 12:07:32,369 Exception in callback None()
# handle: <Handle cancelled>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1391, in _do_ssl_handshake
#     self.socket.do_handshake()
#   File "/opt/conda/lib/python3.7/ssl.py", line 1139, in do_handshake
#     self._sslobj.do_handshake()
# ssl.SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate (_ssl.c:1091)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 696, in _handle_events
#     self._handle_read()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1478, in _handle_read
#     self._do_ssl_handshake()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1409, in _do_ssl_handshake
#     return self.close(exc_info=err)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 189, in _handle_events
#     handler_func(fileobj, events)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 732, in _handle_events
#     self.close(exc_info=e)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
# ERROR: 2022-02-18 12:07:32,375 Exception in callback None()
# handle: <Handle cancelled>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1391, in _do_ssl_handshake
#     self.socket.do_handshake()
#   File "/opt/conda/lib/python3.7/ssl.py", line 1139, in do_handshake
#     self._sslobj.do_handshake()
# ssl.SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate (_ssl.c:1091)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 696, in _handle_events
#     self._handle_read()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1478, in _handle_read
#     self._do_ssl_handshake()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1409, in _do_ssl_handshake
#     return self.close(exc_info=err)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 189, in _handle_events
#     handler_func(fileobj, events)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 732, in _handle_events
#     self.close(exc_info=e)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
# ERROR: 2022-02-18 12:07:32,383 Exception in callback None()
# handle: <Handle cancelled>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1391, in _do_ssl_handshake
#     self.socket.do_handshake()
#   File "/opt/conda/lib/python3.7/ssl.py", line 1139, in do_handshake
#     self._sslobj.do_handshake()
# ssl.SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate (_ssl.c:1091)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 696, in _handle_events
#     self._handle_read()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1478, in _handle_read
#     self._do_ssl_handshake()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1409, in _do_ssl_handshake
#     return self.close(exc_info=err)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 189, in _handle_events
#     handler_func(fileobj, events)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 732, in _handle_events
#     self.close(exc_info=e)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
# ERROR: 2022-02-18 12:07:32,412 Exception in callback None()
# handle: <Handle cancelled>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1391, in _do_ssl_handshake
#     self.socket.do_handshake()
#   File "/opt/conda/lib/python3.7/ssl.py", line 1139, in do_handshake
#     self._sslobj.do_handshake()
# ssl.SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate (_ssl.c:1091)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 696, in _handle_events
#     self._handle_read()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1478, in _handle_read
#     self._do_ssl_handshake()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1409, in _do_ssl_handshake
#     return self.close(exc_info=err)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 189, in _handle_events
#     handler_func(fileobj, events)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 732, in _handle_events
#     self.close(exc_info=e)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
# ERROR: 2022-02-18 12:07:32,416 Exception in callback None()
# handle: <Handle cancelled>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1391, in _do_ssl_handshake
#     self.socket.do_handshake()
#   File "/opt/conda/lib/python3.7/ssl.py", line 1139, in do_handshake
#     self._sslobj.do_handshake()
# ssl.SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate (_ssl.c:1091)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 696, in _handle_events
#     self._handle_read()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1478, in _handle_read
#     self._do_ssl_handshake()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1409, in _do_ssl_handshake
#     return self.close(exc_info=err)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 189, in _handle_events
#     handler_func(fileobj, events)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 732, in _handle_events
#     self.close(exc_info=e)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
# ERROR: 2022-02-18 12:07:32,426 Exception in callback None()
# handle: <Handle cancelled>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1391, in _do_ssl_handshake
#     self.socket.do_handshake()
#   File "/opt/conda/lib/python3.7/ssl.py", line 1139, in do_handshake
#     self._sslobj.do_handshake()
# ssl.SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate (_ssl.c:1091)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 696, in _handle_events
#     self._handle_read()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1478, in _handle_read
#     self._do_ssl_handshake()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1409, in _do_ssl_handshake
#     return self.close(exc_info=err)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 189, in _handle_events
#     handler_func(fileobj, events)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 732, in _handle_events
#     self.close(exc_info=e)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
# distributed.client - ERROR - Failed to reconnect to scheduler after 30.00 seconds, closing client
# distributed.client - ERROR - Failed to reconnect to scheduler after 30.00 seconds, closing client
# distributed.client - ERROR - Failed to reconnect to scheduler after 30.00 seconds, closing client
# distributed.client - ERROR - Failed to reconnect to scheduler after 30.00 seconds, closing client
# distributed.client - ERROR - Failed to reconnect to scheduler after 30.00 seconds, closing client
# ERROR: 2022-02-18 12:07:32,470 Exception in callback None()
# handle: <Handle cancelled>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1391, in _do_ssl_handshake
#     self.socket.do_handshake()
#   File "/opt/conda/lib/python3.7/ssl.py", line 1139, in do_handshake
#     self._sslobj.do_handshake()
# ssl.SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate (_ssl.c:1091)
#
# ...
#     handler_func(fileobj, events)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 732, in _handle_events
#     self.close(exc_info=e)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
# ERROR: 2022-02-18 12:09:21,352 Exception in callback None()
# handle: <Handle cancelled>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1391, in _do_ssl_handshake
#     self.socket.do_handshake()
#   File "/opt/conda/lib/python3.7/ssl.py", line 1139, in do_handshake
#     self._sslobj.do_handshake()
# OSError: [Errno 0] Error
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 696, in _handle_events
#     self._handle_read()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1478, in _handle_read
#     self._do_ssl_handshake()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1429, in _do_ssl_handshake
#     return self.close(exc_info=err)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 189, in _handle_events
#     handler_func(fileobj, events)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 732, in _handle_events
#     self.close(exc_info=e)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
# ERROR: 2022-02-18 12:09:21,353 Exception in callback None()
# handle: <Handle cancelled>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1391, in _do_ssl_handshake
#     self.socket.do_handshake()
#   File "/opt/conda/lib/python3.7/ssl.py", line 1139, in do_handshake
#     self._sslobj.do_handshake()
# OSError: [Errno 0] Error
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 696, in _handle_events
#     self._handle_read()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1478, in _handle_read
#     self._do_ssl_handshake()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1429, in _do_ssl_handshake
#     return self.close(exc_info=err)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 189, in _handle_events
#     handler_func(fileobj, events)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 732, in _handle_events
#     self.close(exc_info=e)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
# ERROR: 2022-02-18 12:09:21,355 Exception in callback None()
# handle: <Handle cancelled>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1391, in _do_ssl_handshake
#     self.socket.do_handshake()
#   File "/opt/conda/lib/python3.7/ssl.py", line 1139, in do_handshake
#     self._sslobj.do_handshake()
# OSError: [Errno 0] Error
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 696, in _handle_events
#     self._handle_read()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1478, in _handle_read
#     self._do_ssl_handshake()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1429, in _do_ssl_handshake
#     return self.close(exc_info=err)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 189, in _handle_events
#     handler_func(fileobj, events)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 732, in _handle_events
#     self.close(exc_info=e)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
# ERROR: 2022-02-18 12:09:21,357 Exception in callback None()
# handle: <Handle cancelled>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1391, in _do_ssl_handshake
#     self.socket.do_handshake()
#   File "/opt/conda/lib/python3.7/ssl.py", line 1139, in do_handshake
#     self._sslobj.do_handshake()
# OSError: [Errno 0] Error
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 696, in _handle_events
#     self._handle_read()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1478, in _handle_read
#     self._do_ssl_handshake()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1429, in _do_ssl_handshake
#     return self.close(exc_info=err)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 189, in _handle_events
#     handler_func(fileobj, events)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 732, in _handle_events
#     self.close(exc_info=e)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
# ERROR: 2022-02-18 12:09:21,358 Exception in callback None()
# handle: <Handle cancelled>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1391, in _do_ssl_handshake
#     self.socket.do_handshake()
#   File "/opt/conda/lib/python3.7/ssl.py", line 1139, in do_handshake
#     self._sslobj.do_handshake()
# OSError: [Errno 0] Error
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 696, in _handle_events
#     self._handle_read()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1478, in _handle_read
#     self._do_ssl_handshake()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1429, in _do_ssl_handshake
#     return self.close(exc_info=err)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 189, in _handle_events
#     handler_func(fileobj, events)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 732, in _handle_events
#     self.close(exc_info=e)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
# ERROR: 2022-02-18 12:09:21,360 Exception in callback None()
# handle: <Handle cancelled>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1391, in _do_ssl_handshake
#     self.socket.do_handshake()
#   File "/opt/conda/lib/python3.7/ssl.py", line 1139, in do_handshake
#     self._sslobj.do_handshake()
# OSError: [Errno 0] Error
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 696, in _handle_events
#     self._handle_read()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1478, in _handle_read
#     self._do_ssl_handshake()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1429, in _do_ssl_handshake
#     return self.close(exc_info=err)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 189, in _handle_events
#     handler_func(fileobj, events)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 732, in _handle_events
#     self.close(exc_info=e)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
# ERROR: 2022-02-18 12:09:21,361 Exception in callback None()
# handle: <Handle cancelled>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1391, in _do_ssl_handshake
#     self.socket.do_handshake()
#   File "/opt/conda/lib/python3.7/ssl.py", line 1139, in do_handshake
#     self._sslobj.do_handshake()
# OSError: [Errno 0] Error
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 696, in _handle_events
#     self._handle_read()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1478, in _handle_read
#     self._do_ssl_handshake()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1429, in _do_ssl_handshake
#     return self.close(exc_info=err)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 189, in _handle_events
#     handler_func(fileobj, events)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 732, in _handle_events
#     self.close(exc_info=e)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
# ERROR: 2022-02-18 12:09:21,395 Exception in callback None()
# handle: <Handle cancelled>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1391, in _do_ssl_handshake
#     self.socket.do_handshake()
#   File "/opt/conda/lib/python3.7/ssl.py", line 1139, in do_handshake
#     self._sslobj.do_handshake()
# OSError: [Errno 0] Error
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 696, in _handle_events
#     self._handle_read()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1478, in _handle_read
#     self._do_ssl_handshake()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 1429, in _do_ssl_handshake
#     return self.close(exc_info=err)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 189, in _handle_events
#     handler_func(fileobj, events)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 732, in _handle_events
#     self.close(exc_info=e)
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 611, in close
#     self._signal_closed()
#   File "/opt/conda/lib/python3.7/site-packages/tornado/iostream.py", line 641, in _signal_closed
#     self._ssl_connect_future.exception()
# concurrent.futures._base.CancelledError
