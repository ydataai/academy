# %% [markdown]
# # Using YData to synthesize sequential transactional data
#
# ## Context
#
# Payments data is one of the most common types of transactional datasets, and for many business areas one of the most valuable. However, it is particularly sensitive and has complex underlying logic governing it, which makes it a perfect test bed for data quality assessment and synthetic data generation.
#
# The dataset _“PaySim: A financial mobile money simulator for fraud detection”_ is a case study based on a real company that developed a mobile money implementation which provided mobile phone users the ability to transfer money between themselves using the phone as a sort of electronic wallet.

# %% [markdown]
# **Outline of this document**
#
# - Ingesting and understanding a transactional financial dataset, including abidance by business logic
# - Training a synthetic data generator over the dataset
# - Generating a synthetic version of the dataset, integrating the aforementioned business logic
# - Evaluating the statistical fidelity and coherence of the generated data

# %% [markdown]
# ## Dataset: PaySim

# %% [markdown]
# PaySim simulates mobile money transactions based on a sample of real transactions (extracted from one month of financial logs from a mobile money service implemented in an African country). The original logs were provided by a multinational company, who is the provider of a mobile financial service currently running in more than 14 countries all around the world.
#
# The PaySim version used is a custom one generated through the code on the [PaySim GitHub repository](https://github.com/EdgarLopezPhD/PaySim) and based on the paper [_PaySim: A financial mobile money simulator for fraud detection_](https://www.researchgate.net/publication/313138956_PAYSIM_A_FINANCIAL_MOBILE_MONEY_SIMULATOR_FOR_FRAUD_DETECTION).

# %% [markdown]
# ### Loading the dataset
#
# YData's platform is fully integrated - this means that any source of data created through the UI can be easily consumed within the Labs (via the [Platform SDK](https://github.com/ydataai/academy/blob/master/1%20-%20platform-sdk/ui-to-sdk-examples.ipynb)) for further exploration, leveraging the platform's built-in scalability. Alternatively, YData's [Connectors](https://github.com/ydataai/academy/tree/master/2%20-%20connectors) could also be used.
#
# Below, the Platform SDK will be used.

# %% [raw]
# # Importing YData's packages
# from ydata.platform.datasources import DataSources
# from ydata.metadata import Metadata
# from ydata.dataset import Dataset
#
# # Creating a Dataset from the Data Source
# datasource = DataSources.get(uid='fe9e35ba-17bd-4dd4-b2d5-844764323028', namespace='d134e271-5e3c-4f32-a657-ee6ce8936820')
# dataset = datasource.read()
#
# # Quickly previewing the Dataset
# dataset.head()

# %%
from ydata.dataset import Dataset

dataset = Dataset(df)

# %%
dataset.shape(lazy_eval=False)
# Out:
# (3440390, 13)

# %%
dataset.value_counts(col='isUnauthorizedOverdraft')
# Out:
# 0    3382697
# 1      57693
# Name: isUnauthorizedOverdraft, dtype: int64

# %%
dataset.value_counts(col='isFraud')
# Out:
# 0    3439000
# 1       1390
# Name: isFraud, dtype: int64

# %%
dataset.value_counts(col='isFlaggedFraud')
# Out:
# 0    3440390
# Name: isFlaggedFraud, dtype: int64

# %%
dataset.uniques('action')
# Out:
# 5

# %% [markdown]
# From this quick peek at the dataset, we can identify several things:
#
# - about 3.4 million transactions
# - `time` is our sequential indicator (`step` represents an hour of transactions, `time` is a linear indicator of the transaction order)
# - existing features:
#     - features describing the financial operation and its flow (`type`, `amount`, `nameOrig` and `nameDest`)
#     - features keeping track of the balance of each financial entity (`oldbalanceDest`, `newbalanceDest`, `oldbalanceOrg`, `newbalanceOrig`)
#     - features related with fraud (`isFlaggedFraud`, automatically detected potential frauds and `isFraud`, the real assessment).
# - 5 types of financial transactions: `CASH_IN`, `CASH_OUT`, `PAYMENT`, `TRANSFER`, `DEBIT` (ordered by decreasing relative frequency)
# - the existance of `isUnauthorizedOverdraft` events due to lack of funds (~1.67% of all transactions)
# - the existence of fraudulent events in `isFraud`, with the dataset revealing a huge imbalance: only ~0.04% of all transactions were fraudulent
#   - the `isFlaggedFraud` column is the result of a naive rule automatically flaggging transfers above 200k. This dataset in particular contains no such events.

# %% [markdown]
# ### Evaluating data quality

# %% [markdown]
# The automated profiling available on the platform heavily complements these insights above with univariante and multivariate profiling plus automatic detection of potential data quality issues. To access these data quality warnigs, useful to identify potential issues which must be solved prior to data synthesis, a `Metadata` object, holding information about the dataset, must be created.

# %%
from ydata.metadata import Metadata
# Creating a Metadata (where warnings can be reviewed) from the Dataset
metadata = Metadata(dataset)
print(metadata)
# Out:
# [########################################] | 100% Completed | 216.16 ms
# [##############################          ] | 75% Completed | 11.03 sms
# /home/ydata/.venv/lib/python3.10/site-packages/dask/array/core.py:4917: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# [########################################] | 100% Completed | 18.17 s
# [########################################] | 100% Completed | 33.19 ss
# Metadata Summary
#
# Dataset type: TABULAR
# Dataset attributes:
# Number of columns: 13
# Number of rows: 3440390
# Duplicate rows: 0
# Target column:
#
# Column detail:
#                      Column    Data type Variable type Characteristics
# 0                      time    numerical           int
# 1                      step    numerical           int
# 2                    action  categorical        string
# 3                    amount    numerical         float
# 4                  nameOrig       string        string
# 5            oldBalanceOrig    numerical         float
# 6            newBalanceOrig    numerical         float
# 7                  nameDest       string        string
# 8            oldBalanceDest    numerical         float
# 9            newBalanceDest    numerical         float
# 10                  isFraud  categorical           int
# 11           isFlaggedFraud  categorical           int
# 12  isUnauthorizedOverdraft  categorical           int
#
# Warnings:
#        Warning                                                                                                                                                                                                                                      Columns
# 0     skewness                                                                                                                                                               [step, amount, oldBalanceOrig, newBalanceOrig, oldBalanceDest, newBalanceDest]
# 1  cardinality                                                                                                                                                                                                                         [nameOrig, nameDest]
# 2     constant                                                                                                                                                                                                                             [isFlaggedFraud]
# 3        zeros                                                                                                                                                                       [time, oldBalanceOrig, newBalanceOrig, oldBalanceDest, newBalanceDest]
# 4  correlation  [time|step, time|oldBalanceDest, time|newBalanceDest, step|oldBalanceDest, step|newBalanceDest, action|amount, action|nameDest, action|oldBalanceDest, action|newBalanceDest, oldBalanceOrig|newBalanceOrig, oldBalanceDest|newBalanceDest]
# 5    imbalance                                                                                                                                                                                                   [action, isFraud, isUnauthorizedOverdraft]

# %% [markdown]
# This gives us additional information about the dataset: balances and amounts have highly skewed distributions, which suggests different transactions and client profiles. We also seem to have a large number of entities represented in this dataset, judging by the high cardinality warnings in our origin and destination entities.
#
# On the other hand, we see no issues with high missingness of values or duplicates. For now, we will drop the `step` column, as we have seen it encodes similar information as the `time` and explictly selec

# %%
dataset.drop_columns(['step', 'isFlaggedFraud'], inplace=True)

# %%
dataset.columns
# Out:
# ['time',
#  'action',
#  'amount',
#  'nameOrig',
#  'oldBalanceOrig',
#  'newBalanceOrig',
#  'nameDest',
#  'oldBalanceDest',
#  'newBalanceDest',
#  'isFraud',
#  'isUnauthorizedOverdraft']

# %% [markdown]
# ### Validation of business rules

# %% [markdown]
# A dataset not abiding by the expected business rules may silently go unnoticed through all the phases of a project and fail to deliver any business value when finally live. As such, it's important to validate these kind of constraints and business logic.
#
# YData's `ConstraintEngine` can be used for validation of several type of arbitrary row and column-wise constraints (per-entity, if required).

# %% [markdown]
# #### Which business rules and constraints does this dataset have?
#
# Stemming from its transactional-financial nature and given the [extra context available on Kaggle](https://www.kaggle.com/datasets/ealaxi/paysim1) and in the original paper, some implicit and explicit business rules can be derived for this dataset:
#
# - There are 3 different types of entities:
#     - _Banks_, which are always destination entities and whose balance is always 0
#     - _Customers_, which can be either origin or destination entities
#     - _Merchants_, which are always destination entities
# - Rejected overdraft operations (`isUnauthorizedOverdraft==1`), which can happen for all transaction types apart from `CASH_IN`, do not go through - the balances of both the origin and destination entity as kept.
# - Fraudulent events are an _a posteriori_ label, so all transactions marked as fraudulent (`isFraud == 1`) go through normally.
# - The `amount` column should only assume positive values (as the signal of the transaction depends on the `action`).
# - For every transaction and throughout time, the state of each entity (its balance) should be coherent with its interaction with other entities. This depends on the type of transaction:
#     - `CASH_IN`: always from _Customer_ to _Merchant_, with the origin balance increasing and the destination balance staying the same.
#     - `CASH_OUT`: always from _Customer_ to _Merchant_, with the origin balance decreasing and the destination balance staying the same.
#     - `PAYMENT`: always from _Customer_ to _Merchant_, with the origin balance decreasing and the destination balance increasing.
#     - `TRANSFER`: always from _Customer_ to _Customer_, with the origin balance decreasing and the destination balance increasing.
#     - `DEBIT`: always from _Customer_ to _Bank_, with the origin balance decreasing and the destination balance staying the same (0, as it is a _Bank_)
#
# Additionally, it's possible that the starting balances of some entities (_Customers_ or _Merchants_) are negative. YData's constraints engine allows us to express all this. Let's validate some of these.

# %%
from ydata.constraints.engine import ConstraintEngine
from ydata.constraints.rows import GreaterThan, Positive, CustomConstraint

# Create the custom constrains for the dataset

# Validate only customers (C) are origin entities and all destination entities are either Customers, Banks or Merchants
def validate_entities(df):
    return (df.nameOrig.str[0] == 'C') & (df.nameDest.str[0].isin(['C', 'B', 'M']))

# Validate what happens to the balances during a rejected overdraft
def validate_overdraft(r):
    if r.isUnauthorizedOverdraft == 1:
        if abs(r.newBalanceOrig-r.oldBalanceOrig) < 1e-6 and abs(r.newBalanceDest-r.oldBalanceDest) < 1e-6:
            return True
        else:
            return False
    else:
        return True

# Validate whether the balances are updated according to the operation type
def validate_interactions(r):

    ops_map = {
            'CASH_IN': [1, 0],
            'CASH_OUT': [-1, 0],
            'PAYMENT': [-1, 1],
            'TRANSFER': [-1, 1],
            'DEBIT': [-1, 0]
    }

    if r.isUnauthorizedOverdraft:
        return True # overdraft constraints are handled elsewhere

    op = r.action
    amount = r.amount

    try:
        assert abs(r.newBalanceOrig - (r.oldBalanceOrig + (amount*ops_map[op][0]))) <= 0.02
        assert abs(r.newBalanceDest - (r.oldBalanceDest + (amount*ops_map[op][1]))) <= 0.02
        return True
    except AssertionError:
        return False


# Some other out-of-the-box constrains are also available like GreaterThan,
# which checks whether a colum(n) is(are) greater than a certain provided value(s)

c1 = Positive(columns=['amount'])
c2 = CustomConstraint(name="Validate type of origin entity | axis=0",
                       check=validate_entities,
                       available_columns=['nameOrig', 'nameDest'],
                       axis=0)
c3 = CustomConstraint(name="Validate overdraft behaviour | axis=1",
                       check=validate_overdraft,
                       available_columns=['isUnauthorizedOverdraft', 'oldBalanceOrig', 'newBalanceOrig', 'oldBalanceDest', 'newBalanceDest'],
                       axis=1)

c4 = CustomConstraint(name="Balances updates coherence | axis=1",
                       check=validate_interactions,
                       available_columns=["isUnauthorizedOverdraft", "action", "amount", "oldBalanceOrig", "newBalanceOrig", "oldBalanceDest", "newBalanceDest"],
                       axis=1)

engine = ConstraintEngine()
engine.add_constraints([c1, c2, c3, c4])

# %% [markdown]
# #### Running the validation

# %%
# Getting the summary view of the constraints engine
engine.validate(dataset)
engine.summary()
# Out:
# /home/ydata/.venv/lib/python3.10/site-packages/ydata/dataset/dataset.py:80: UserWarning: All the input Variable Types were set as `string` or `object`. It is recommend to revise the VariableType settings for optimal results.
#   warnings.warn(
# /home/ydata/.venv/lib/python3.10/site-packages/dask/dataframe/core.py:6000: UserWarning:
# You did not provide metadata, so Dask is running your function on a small dataset to guess output types. It is possible that Dask will guess incorrectly.
# To provide an explicit output types or to silence this message, please provide the `meta=` keyword, as described in the map or apply function that you are using.
#   Before: .apply(func)
#   After:  .apply(func, meta=(None, 'bool'))
#
#   warnings.warn(meta_warning(meta))
# /home/ydata/.venv/lib/python3.10/site-packages/dask/dataframe/core.py:6000: UserWarning:
# You did not provide metadata, so Dask is running your function on a small dataset to guess output types. It is possible that Dask will guess incorrectly.
# To provide an explicit output types or to silence this message, please provide the `meta=` keyword, as described in the map or apply function that you are using.
#   Before: .apply(func)
#   After:  .apply(func, meta=(None, 'bool'))
#
#   warnings.warn(meta_warning(meta))
# {'rows_violation_count': 3429852,
#  'rows_violation_ratio': 0.9969369751685129,
#  'violation_per_constraint': {"Positive(columns=['amount'])": {'rows_violation_count': 3429852,
#    'rows_violation_ratio': 0.9969369751685129,
#    'validation_time': 0.68},
#   'Validate type of origin entity | axis=0': {'rows_violation_count': 0,
#    'rows_violation_ratio': 0.0,
#    'validation_time': 4.53},
#   'Validate overdraft behaviour | axis=1': {'rows_violation_count': 0,
#    'rows_violation_ratio': 0.0,
#    'validation_time': 49.4},
#   'Balances updates coherence | axis=1': {'rows_violation_count': 0,
#    'rows_violation_ratio': 0.0,
#    'validation_time': 236.12}}}

# %%
engine.summary()
# Out:
# {'rows_violation_count': 3429852,
#  'rows_violation_ratio': 0.9969369751685129,
#  'violation_per_constraint': {"Positive(columns=['amount'])": {'rows_violation_count': 3429852,
#    'rows_violation_ratio': 0.9969369751685129,
#    'validation_time': 0.68},
#   'Validate type of origin entity | axis=0': {'rows_violation_count': 0,
#    'rows_violation_ratio': 0.0,
#    'validation_time': 4.53},
#   'Validate overdraft behaviour | axis=1': {'rows_violation_count': 0,
#    'rows_violation_ratio': 0.0,
#    'validation_time': 49.4},
#   'Balances updates coherence | axis=1': {'rows_violation_count': 0,
#    'rows_violation_ratio': 0.0,
#    'validation_time': 236.12}}}

# %% [markdown]
# We can verify that, apart from the rounding error in transaction processing (quite significant, at 2 cents per transaction), the dataset is consistent with the identified business logic and does not show significant outliers.
#
# We can noew proceed to the synthesization step with renewed confidence. **The quality of a synthetic dataset is heavily influenced by the quality of the original dataset**. Thus, it becomes critical to first spend time understanding a dataset and identifying potential quality issues prior to synthesizing, before being surprised by new and unexpected behaviours inherited from the original data.

# %% [markdown]
# ## Creating a synthetic replica of the PaySim dataset

# %% [markdown]
# By now, it is clear that for each transaction, there is a lot of underlying logic governing the evolution of the balances and the interactions between entities. This needs to be taken into account while preparing a synthesis process.
#
# If we synthesize directly both the transaction amount and the balances, we are at risk of losing the coherence in the entity states across time, as we are not putting strict guarantees in place that their balances are correctly updated.
#
# As such, we can opt to **only synthesize the amounts and types of operations - guaranteeing those distributions mimick the original dataset - and manually reconstruct the balances after synthesization based on the business logic we described above**. Overdrafts also have a clear definition (when the amount surpasses the available balance), so we don't need to synthesize them - we can just detect and flag them during post-processing.

# %% [markdown]
# Based on our considerations above, we select the relevant variables for synthesis, by filtering out the balances and the rejected overdraft column. We **only synthesize the time, the type and amount of the transaction, the origin and destination entities and whether or not the transaction is fraudulent**.

# %%
#Selecting the columns to be synthesized

sel_dataset = dataset[['time',
                     'action',
                     'amount',
                     'nameOrig',
                     'nameDest',
                     'isFraud']]

# %% [markdown]
#  A `Metadata` object is where we configure all the settings for the synthetization. Let's create one to feed to our Synthesizers.
#
# For a multi-entity time series synthesizer, we need to indicate which columns define the sequential ordering and which specify the entities, so that our synthesized dataset presents per-entity sequentiality and coherence.

# %%
from ydata.utils.data_types import DataType, VariableType
from ydata.dataset.dataset_type import DatasetType
from ydata.synthesizers.timeseries.model import TimeSeriesSynthesizer

# Creating the Metadata object for the synthesis

dataset_attrs = {
     "sortbykey": "time",
     #"entities": ["nameOrig", "nameDest"]
}

m = Metadata(sel_dataset,
             dataset_attrs,
             dataset_type=DatasetType.TIMESERIES)
# Out:
# [########################################] | 100% Completed | 747.90 ms
# [########################################] | 100% Completed | 450.05 ms
# [########################################] | 100% Completed | 17.11 s
# [########################################] | 100% Completed | 14.46 ss

# %% [markdown]
# YData's `TimeSeriesSynthesizer` abstracts a lot of the complexity related with sequential data synthesis, by automatically selecting the best from a library of state-of-the-art models and orchestrating all the training. All via a simple interface. Training and sampling a Synthesizer takes, literally, 3 lines of code.

# %%
synthesizer = TimeSeriesSynthesizer()
synthesizer.fit(sel_dataset, metadata=m)
# Out:
# INFO: 2023-09-18 11:28:30,160 [SYNTHESIZER] - Initializing Time Series SYNTHESIZER.
# INFO: 2023-09-18 11:28:30,162 [SYNTHESIZER] - Number columns considered for synth: 6
# INFO: 2023-09-18 11:28:35,438 [SYNTHESIZER] - Starting the synthetic data modeling process over 115x1 blocks.
# INFO: 2023-09-18 11:28:35,439 [SYNTHESIZER] - Generating pipeline for segment (-0.001, 29916.426]
# INFO: 2023-09-18 11:28:35,447 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:28:35,457 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:28:35,458 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:28:44,002 [SYNTHESIZER] - Generating pipeline for segment (29916.426, 59832.852]
# INFO: 2023-09-18 11:28:44,007 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:28:44,014 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:28:44,015 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:28:52,559 [SYNTHESIZER] - Generating pipeline for segment (59832.852, 89749.278]
# INFO: 2023-09-18 11:28:52,564 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:28:52,571 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:28:52,572 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:29:00,953 [SYNTHESIZER] - Generating pipeline for segment (89749.278, 119665.704]
# INFO: 2023-09-18 11:29:00,958 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:29:00,964 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:29:00,965 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:29:09,657 [SYNTHESIZER] - Generating pipeline for segment (119665.704, 149582.13]
# INFO: 2023-09-18 11:29:09,662 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:29:09,669 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:29:09,670 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:29:18,343 [SYNTHESIZER] - Generating pipeline for segment (149582.13, 179498.557]
# INFO: 2023-09-18 11:29:18,348 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:29:18,355 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:29:18,356 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:29:27,374 [SYNTHESIZER] - Generating pipeline for segment (179498.557, 209414.983]
# INFO: 2023-09-18 11:29:27,379 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:29:27,385 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:29:27,386 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:29:35,711 [SYNTHESIZER] - Generating pipeline for segment (209414.983, 239331.409]
# INFO: 2023-09-18 11:29:35,716 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:29:35,722 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:29:35,724 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:29:44,539 [SYNTHESIZER] - Generating pipeline for segment (239331.409, 269247.835]
# INFO: 2023-09-18 11:29:44,544 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:29:44,551 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:29:44,552 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:29:53,013 [SYNTHESIZER] - Generating pipeline for segment (269247.835, 299164.261]
# INFO: 2023-09-18 11:29:53,018 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:29:53,025 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:29:53,026 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:30:01,632 [SYNTHESIZER] - Generating pipeline for segment (299164.261, 329080.687]
# INFO: 2023-09-18 11:30:01,637 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:30:01,644 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:30:01,644 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:30:10,332 [SYNTHESIZER] - Generating pipeline for segment (329080.687, 358997.113]
# INFO: 2023-09-18 11:30:10,337 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:30:10,344 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:30:10,345 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:30:19,268 [SYNTHESIZER] - Generating pipeline for segment (358997.113, 388913.539]
# INFO: 2023-09-18 11:30:19,273 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:30:19,280 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:30:19,281 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:30:27,856 [SYNTHESIZER] - Generating pipeline for segment (388913.539, 418829.965]
# INFO: 2023-09-18 11:30:27,861 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:30:27,868 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:30:27,868 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:30:36,287 [SYNTHESIZER] - Generating pipeline for segment (418829.965, 448746.391]
# INFO: 2023-09-18 11:30:36,292 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:30:36,299 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:30:36,300 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:30:44,646 [SYNTHESIZER] - Generating pipeline for segment (448746.391, 478662.817]
# INFO: 2023-09-18 11:30:44,651 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:30:44,658 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:30:44,658 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:30:53,120 [SYNTHESIZER] - Generating pipeline for segment (478662.817, 508579.243]
# INFO: 2023-09-18 11:30:53,125 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:30:53,132 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:30:53,133 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:31:01,907 [SYNTHESIZER] - Generating pipeline for segment (508579.243, 538495.67]
# INFO: 2023-09-18 11:31:01,912 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:31:01,919 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:31:01,920 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:31:10,464 [SYNTHESIZER] - Generating pipeline for segment (538495.67, 568412.096]
# INFO: 2023-09-18 11:31:10,469 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:31:10,476 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:31:10,477 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:31:19,423 [SYNTHESIZER] - Generating pipeline for segment (568412.096, 598328.522]
# INFO: 2023-09-18 11:31:19,428 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:31:19,435 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:31:19,436 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:31:28,293 [SYNTHESIZER] - Generating pipeline for segment (598328.522, 628244.948]
# INFO: 2023-09-18 11:31:28,299 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:31:28,307 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:31:28,307 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:31:36,832 [SYNTHESIZER] - Generating pipeline for segment (628244.948, 658161.374]
# INFO: 2023-09-18 11:31:36,837 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:31:36,844 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:31:36,844 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:31:45,650 [SYNTHESIZER] - Generating pipeline for segment (658161.374, 688077.8]
# INFO: 2023-09-18 11:31:45,655 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:31:45,662 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:31:45,663 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:31:54,521 [SYNTHESIZER] - Generating pipeline for segment (688077.8, 717994.226]
# INFO: 2023-09-18 11:31:54,526 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:31:54,533 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:31:54,534 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:32:03,096 [SYNTHESIZER] - Generating pipeline for segment (717994.226, 747910.652]
# INFO: 2023-09-18 11:32:03,101 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:32:03,108 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:32:03,109 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:32:11,791 [SYNTHESIZER] - Generating pipeline for segment (747910.652, 777827.078]
# INFO: 2023-09-18 11:32:11,796 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:32:11,804 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:32:11,805 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:32:20,353 [SYNTHESIZER] - Generating pipeline for segment (777827.078, 807743.504]
# INFO: 2023-09-18 11:32:20,358 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:32:20,364 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:32:20,365 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:32:28,759 [SYNTHESIZER] - Generating pipeline for segment (807743.504, 837659.93]
# INFO: 2023-09-18 11:32:28,764 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:32:28,771 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:32:28,771 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:32:37,359 [SYNTHESIZER] - Generating pipeline for segment (837659.93, 867576.357]
# INFO: 2023-09-18 11:32:37,364 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:32:37,371 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:32:37,372 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:32:45,936 [SYNTHESIZER] - Generating pipeline for segment (867576.357, 897492.783]
# INFO: 2023-09-18 11:32:45,941 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:32:45,948 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:32:45,949 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:32:54,805 [SYNTHESIZER] - Generating pipeline for segment (897492.783, 927409.209]
# INFO: 2023-09-18 11:32:54,810 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:32:54,817 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:32:54,818 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:33:03,580 [SYNTHESIZER] - Generating pipeline for segment (927409.209, 957325.635]
# INFO: 2023-09-18 11:33:03,585 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:33:03,592 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:33:03,593 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:33:12,399 [SYNTHESIZER] - Generating pipeline for segment (957325.635, 987242.061]
# INFO: 2023-09-18 11:33:12,404 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:33:12,411 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:33:12,411 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:33:21,496 [SYNTHESIZER] - Generating pipeline for segment (987242.061, 1017158.487]
# INFO: 2023-09-18 11:33:21,501 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:33:21,508 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:33:21,509 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:33:30,592 [SYNTHESIZER] - Generating pipeline for segment (1017158.487, 1047074.913]
# INFO: 2023-09-18 11:33:30,597 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:33:30,605 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:33:30,606 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:33:39,396 [SYNTHESIZER] - Generating pipeline for segment (1047074.913, 1076991.339]
# INFO: 2023-09-18 11:33:39,401 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:33:39,408 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:33:39,409 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:33:48,669 [SYNTHESIZER] - Generating pipeline for segment (1076991.339, 1106907.765]
# INFO: 2023-09-18 11:33:48,674 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:33:48,681 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:33:48,682 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:33:57,368 [SYNTHESIZER] - Generating pipeline for segment (1106907.765, 1136824.191]
# INFO: 2023-09-18 11:33:57,373 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:33:57,380 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:33:57,381 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:34:06,145 [SYNTHESIZER] - Generating pipeline for segment (1136824.191, 1166740.617]
# INFO: 2023-09-18 11:34:06,150 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:34:06,157 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:34:06,157 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:34:14,525 [SYNTHESIZER] - Generating pipeline for segment (1166740.617, 1196657.043]
# INFO: 2023-09-18 11:34:14,530 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:34:14,537 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:34:14,538 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:34:23,079 [SYNTHESIZER] - Generating pipeline for segment (1196657.043, 1226573.47]
# INFO: 2023-09-18 11:34:23,084 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:34:23,091 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:34:23,092 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:34:31,665 [SYNTHESIZER] - Generating pipeline for segment (1226573.47, 1256489.896]
# INFO: 2023-09-18 11:34:31,670 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:34:31,676 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:34:31,677 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:34:40,484 [SYNTHESIZER] - Generating pipeline for segment (1256489.896, 1286406.322]
# INFO: 2023-09-18 11:34:40,490 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:34:40,497 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:34:40,498 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:34:49,227 [SYNTHESIZER] - Generating pipeline for segment (1286406.322, 1316322.748]
# INFO: 2023-09-18 11:34:49,232 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:34:49,239 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:34:49,240 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:34:58,176 [SYNTHESIZER] - Generating pipeline for segment (1316322.748, 1346239.174]
# INFO: 2023-09-18 11:34:58,181 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:34:58,188 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:34:58,189 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:35:07,104 [SYNTHESIZER] - Generating pipeline for segment (1346239.174, 1376155.6]
# INFO: 2023-09-18 11:35:07,110 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:35:07,118 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:35:07,119 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:35:15,913 [SYNTHESIZER] - Generating pipeline for segment (1376155.6, 1406072.026]
# INFO: 2023-09-18 11:35:15,917 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:35:15,924 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:35:15,925 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:35:24,630 [SYNTHESIZER] - Generating pipeline for segment (1406072.026, 1435988.452]
# INFO: 2023-09-18 11:35:24,635 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:35:24,642 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:35:24,643 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:35:33,382 [SYNTHESIZER] - Generating pipeline for segment (1435988.452, 1465904.878]
# INFO: 2023-09-18 11:35:33,387 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:35:33,394 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:35:33,395 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:35:41,966 [SYNTHESIZER] - Generating pipeline for segment (1465904.878, 1495821.304]
# INFO: 2023-09-18 11:35:41,971 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:35:41,978 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:35:41,979 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:35:50,540 [SYNTHESIZER] - Generating pipeline for segment (1495821.304, 1525737.73]
# INFO: 2023-09-18 11:35:50,545 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:35:50,552 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:35:50,553 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:35:59,162 [SYNTHESIZER] - Generating pipeline for segment (1525737.73, 1555654.157]
# INFO: 2023-09-18 11:35:59,167 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:35:59,174 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:35:59,174 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:36:08,025 [SYNTHESIZER] - Generating pipeline for segment (1555654.157, 1585570.583]
# INFO: 2023-09-18 11:36:08,029 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:36:08,036 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:36:08,037 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:36:17,039 [SYNTHESIZER] - Generating pipeline for segment (1585570.583, 1615487.009]
# INFO: 2023-09-18 11:36:17,044 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:36:17,051 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:36:17,052 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:36:25,890 [SYNTHESIZER] - Generating pipeline for segment (1615487.009, 1645403.435]
# INFO: 2023-09-18 11:36:25,896 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:36:25,903 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:36:25,904 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:36:35,052 [SYNTHESIZER] - Generating pipeline for segment (1645403.435, 1675319.861]
# INFO: 2023-09-18 11:36:35,057 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:36:35,064 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:36:35,065 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:36:44,097 [SYNTHESIZER] - Generating pipeline for segment (1675319.861, 1705236.287]
# INFO: 2023-09-18 11:36:44,102 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:36:44,109 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:36:44,110 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:36:52,740 [SYNTHESIZER] - Generating pipeline for segment (1705236.287, 1735152.713]
# INFO: 2023-09-18 11:36:52,746 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:36:52,753 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:36:52,753 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:37:01,080 [SYNTHESIZER] - Generating pipeline for segment (1735152.713, 1765069.139]
# INFO: 2023-09-18 11:37:01,085 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:37:01,091 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:37:01,092 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:37:09,764 [SYNTHESIZER] - Generating pipeline for segment (1765069.139, 1794985.565]
# INFO: 2023-09-18 11:37:09,770 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:37:09,778 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:37:09,779 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:37:18,452 [SYNTHESIZER] - Generating pipeline for segment (1794985.565, 1824901.991]
# INFO: 2023-09-18 11:37:18,457 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:37:18,464 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:37:18,465 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:37:27,280 [SYNTHESIZER] - Generating pipeline for segment (1824901.991, 1854818.417]
# INFO: 2023-09-18 11:37:27,286 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:37:27,292 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:37:27,293 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:37:36,214 [SYNTHESIZER] - Generating pipeline for segment (1854818.417, 1884734.843]
# INFO: 2023-09-18 11:37:36,219 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:37:36,226 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:37:36,227 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:37:45,103 [SYNTHESIZER] - Generating pipeline for segment (1884734.843, 1914651.27]
# INFO: 2023-09-18 11:37:45,109 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:37:45,117 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:37:45,117 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:37:53,784 [SYNTHESIZER] - Generating pipeline for segment (1914651.27, 1944567.696]
# INFO: 2023-09-18 11:37:53,789 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:37:53,796 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:37:53,797 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:38:02,690 [SYNTHESIZER] - Generating pipeline for segment (1944567.696, 1974484.122]
# INFO: 2023-09-18 11:38:02,695 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:38:02,701 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:38:02,702 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:38:11,348 [SYNTHESIZER] - Generating pipeline for segment (1974484.122, 2004400.548]
# INFO: 2023-09-18 11:38:11,353 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:38:11,360 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:38:11,361 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:38:20,189 [SYNTHESIZER] - Generating pipeline for segment (2004400.548, 2034316.974]
# INFO: 2023-09-18 11:38:20,195 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:38:20,202 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:38:20,203 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:38:28,757 [SYNTHESIZER] - Generating pipeline for segment (2034316.974, 2064233.4]
# INFO: 2023-09-18 11:38:28,762 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:38:28,768 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:38:28,769 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:38:37,302 [SYNTHESIZER] - Generating pipeline for segment (2064233.4, 2094149.826]
# INFO: 2023-09-18 11:38:37,307 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:38:37,314 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:38:37,315 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:38:46,317 [SYNTHESIZER] - Generating pipeline for segment (2094149.826, 2124066.252]
# INFO: 2023-09-18 11:38:46,322 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:38:46,329 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:38:46,329 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:38:55,269 [SYNTHESIZER] - Generating pipeline for segment (2124066.252, 2153982.678]
# INFO: 2023-09-18 11:38:55,274 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:38:55,281 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:38:55,282 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:39:04,211 [SYNTHESIZER] - Generating pipeline for segment (2153982.678, 2183899.104]
# INFO: 2023-09-18 11:39:04,216 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:39:04,224 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:39:04,225 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:39:13,083 [SYNTHESIZER] - Generating pipeline for segment (2183899.104, 2213815.53]
# INFO: 2023-09-18 11:39:13,089 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:39:13,096 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:39:13,096 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:39:21,639 [SYNTHESIZER] - Generating pipeline for segment (2213815.53, 2243731.957]
# INFO: 2023-09-18 11:39:21,644 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:39:21,650 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:39:21,651 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:39:30,267 [SYNTHESIZER] - Generating pipeline for segment (2243731.957, 2273648.383]
# INFO: 2023-09-18 11:39:30,272 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:39:30,279 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:39:30,280 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:39:38,963 [SYNTHESIZER] - Generating pipeline for segment (2273648.383, 2303564.809]
# INFO: 2023-09-18 11:39:38,968 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:39:38,975 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:39:38,976 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:39:47,624 [SYNTHESIZER] - Generating pipeline for segment (2303564.809, 2333481.235]
# INFO: 2023-09-18 11:39:47,629 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:39:47,636 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:39:47,637 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:39:56,740 [SYNTHESIZER] - Generating pipeline for segment (2333481.235, 2363397.661]
# INFO: 2023-09-18 11:39:56,745 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:39:56,752 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:39:56,752 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:40:05,656 [SYNTHESIZER] - Generating pipeline for segment (2363397.661, 2393314.087]
# INFO: 2023-09-18 11:40:05,661 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:40:05,668 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:40:05,669 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:40:14,504 [SYNTHESIZER] - Generating pipeline for segment (2393314.087, 2423230.513]
# INFO: 2023-09-18 11:40:14,509 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:40:14,516 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:40:14,517 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:40:23,380 [SYNTHESIZER] - Generating pipeline for segment (2423230.513, 2453146.939]
# INFO: 2023-09-18 11:40:23,385 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:40:23,392 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:40:23,393 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:40:31,999 [SYNTHESIZER] - Generating pipeline for segment (2453146.939, 2483063.365]
# INFO: 2023-09-18 11:40:32,004 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:40:32,011 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:40:32,012 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:40:40,505 [SYNTHESIZER] - Generating pipeline for segment (2483063.365, 2512979.791]
# INFO: 2023-09-18 11:40:40,510 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:40:40,517 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:40:40,517 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:40:49,280 [SYNTHESIZER] - Generating pipeline for segment (2512979.791, 2542896.217]
# INFO: 2023-09-18 11:40:49,285 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:40:49,292 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:40:49,293 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:40:57,998 [SYNTHESIZER] - Generating pipeline for segment (2542896.217, 2572812.643]
# INFO: 2023-09-18 11:40:58,004 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:40:58,010 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:40:58,011 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:41:06,899 [SYNTHESIZER] - Generating pipeline for segment (2572812.643, 2602729.07]
# INFO: 2023-09-18 11:41:06,904 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:41:06,910 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:41:06,911 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:41:15,756 [SYNTHESIZER] - Generating pipeline for segment (2602729.07, 2632645.496]
# INFO: 2023-09-18 11:41:15,761 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:41:15,768 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:41:15,769 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:41:24,378 [SYNTHESIZER] - Generating pipeline for segment (2632645.496, 2662561.922]
# INFO: 2023-09-18 11:41:24,383 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:41:24,390 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:41:24,391 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:41:33,111 [SYNTHESIZER] - Generating pipeline for segment (2662561.922, 2692478.348]
# INFO: 2023-09-18 11:41:33,116 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:41:33,123 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:41:33,124 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:41:41,899 [SYNTHESIZER] - Generating pipeline for segment (2692478.348, 2722394.774]
# INFO: 2023-09-18 11:41:41,905 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:41:41,912 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:41:41,913 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:41:50,525 [SYNTHESIZER] - Generating pipeline for segment (2722394.774, 2752311.2]
# INFO: 2023-09-18 11:41:50,531 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:41:50,539 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:41:50,539 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:41:59,413 [SYNTHESIZER] - Generating pipeline for segment (2752311.2, 2782227.626]
# INFO: 2023-09-18 11:41:59,418 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:41:59,425 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:41:59,426 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:42:08,315 [SYNTHESIZER] - Generating pipeline for segment (2782227.626, 2812144.052]
# INFO: 2023-09-18 11:42:08,320 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:42:08,327 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:42:08,328 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:42:16,992 [SYNTHESIZER] - Generating pipeline for segment (2812144.052, 2842060.478]
# INFO: 2023-09-18 11:42:16,997 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:42:17,004 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:42:17,005 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:42:25,644 [SYNTHESIZER] - Generating pipeline for segment (2842060.478, 2871976.904]
# INFO: 2023-09-18 11:42:25,649 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:42:25,656 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:42:25,656 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:42:34,396 [SYNTHESIZER] - Generating pipeline for segment (2871976.904, 2901893.33]
# INFO: 2023-09-18 11:42:34,401 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:42:34,408 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:42:34,408 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:42:43,012 [SYNTHESIZER] - Generating pipeline for segment (2901893.33, 2931809.757]
# INFO: 2023-09-18 11:42:43,017 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:42:43,024 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:42:43,025 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:42:51,655 [SYNTHESIZER] - Generating pipeline for segment (2931809.757, 2961726.183]
# INFO: 2023-09-18 11:42:51,660 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:42:51,666 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:42:51,667 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:43:00,430 [SYNTHESIZER] - Generating pipeline for segment (2961726.183, 2991642.609]
# INFO: 2023-09-18 11:43:00,435 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:43:00,442 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:43:00,443 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:43:09,569 [SYNTHESIZER] - Generating pipeline for segment (2991642.609, 3021559.035]
# INFO: 2023-09-18 11:43:09,574 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:43:09,581 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:43:09,582 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:43:18,489 [SYNTHESIZER] - Generating pipeline for segment (3021559.035, 3051475.461]
# INFO: 2023-09-18 11:43:18,494 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:43:18,501 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:43:18,502 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:43:27,318 [SYNTHESIZER] - Generating pipeline for segment (3051475.461, 3081391.887]
# INFO: 2023-09-18 11:43:27,323 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:43:27,330 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:43:27,330 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:43:36,119 [SYNTHESIZER] - Generating pipeline for segment (3081391.887, 3111308.313]
# INFO: 2023-09-18 11:43:36,124 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:43:36,131 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:43:36,132 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:43:44,847 [SYNTHESIZER] - Generating pipeline for segment (3111308.313, 3141224.739]
# INFO: 2023-09-18 11:43:44,852 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:43:44,859 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:43:44,860 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:43:53,794 [SYNTHESIZER] - Generating pipeline for segment (3141224.739, 3171141.165]
# INFO: 2023-09-18 11:43:53,799 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:43:53,806 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:43:53,807 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:44:02,764 [SYNTHESIZER] - Generating pipeline for segment (3171141.165, 3201057.591]
# INFO: 2023-09-18 11:44:02,769 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:44:02,776 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:44:02,777 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:44:11,597 [SYNTHESIZER] - Generating pipeline for segment (3201057.591, 3230974.017]
# INFO: 2023-09-18 11:44:11,602 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:44:11,609 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:44:11,610 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:44:20,409 [SYNTHESIZER] - Generating pipeline for segment (3230974.017, 3260890.443]
# INFO: 2023-09-18 11:44:20,414 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:44:20,422 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:44:20,423 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:44:28,961 [SYNTHESIZER] - Generating pipeline for segment (3260890.443, 3290806.87]
# INFO: 2023-09-18 11:44:28,966 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:44:28,973 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:44:28,974 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:44:37,853 [SYNTHESIZER] - Generating pipeline for segment (3290806.87, 3320723.296]
# INFO: 2023-09-18 11:44:37,858 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:44:37,865 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:44:37,866 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:44:46,862 [SYNTHESIZER] - Generating pipeline for segment (3320723.296, 3350639.722]
# INFO: 2023-09-18 11:44:46,867 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:44:46,874 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:44:46,875 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:44:55,754 [SYNTHESIZER] - Generating pipeline for segment (3350639.722, 3380556.148]
# INFO: 2023-09-18 11:44:55,759 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:44:55,767 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:44:55,767 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:45:04,788 [SYNTHESIZER] - Generating pipeline for segment (3380556.148, 3410472.574]
# INFO: 2023-09-18 11:45:04,793 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:45:04,800 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:45:04,800 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 11:45:13,659 [SYNTHESIZER] - Generating pipeline for segment (3410472.574, 3440389.0]
# INFO: 2023-09-18 11:45:13,664 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 11:45:13,671 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 11:45:13,672 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.

# %% [markdown]
# As we want to replicate this dataset, let's generate a sample as large as the original dataset.

# %%
# Generating a sam synthetic data
synth = synthesizer.sample()
# Out:
# INFO: 2023-09-18 11:45:22,763 [SYNTHESIZER] - Start generating model samples.
# INFO: 2023-09-18 11:45:22,765 [SYNTHESIZER] - Sample segment (-0.001, 29916.426]
# INFO: 2023-09-18 11:45:26,038 [SYNTHESIZER] - Sample segment (29916.426, 59832.852]
# INFO: 2023-09-18 11:45:29,159 [SYNTHESIZER] - Sample segment (59832.852, 89749.278]
# INFO: 2023-09-18 11:45:32,209 [SYNTHESIZER] - Sample segment (89749.278, 119665.704]
# INFO: 2023-09-18 11:45:35,385 [SYNTHESIZER] - Sample segment (119665.704, 149582.13]
# INFO: 2023-09-18 11:45:38,552 [SYNTHESIZER] - Sample segment (149582.13, 179498.557]
# INFO: 2023-09-18 11:45:42,082 [SYNTHESIZER] - Sample segment (179498.557, 209414.983]
# INFO: 2023-09-18 11:45:45,132 [SYNTHESIZER] - Sample segment (209414.983, 239331.409]
# INFO: 2023-09-18 11:45:48,348 [SYNTHESIZER] - Sample segment (239331.409, 269247.835]
# INFO: 2023-09-18 11:45:51,515 [SYNTHESIZER] - Sample segment (269247.835, 299164.261]
# INFO: 2023-09-18 11:45:54,762 [SYNTHESIZER] - Sample segment (299164.261, 329080.687]
# INFO: 2023-09-18 11:45:58,010 [SYNTHESIZER] - Sample segment (329080.687, 358997.113]
# INFO: 2023-09-18 11:46:01,301 [SYNTHESIZER] - Sample segment (358997.113, 388913.539]
# INFO: 2023-09-18 11:46:04,509 [SYNTHESIZER] - Sample segment (388913.539, 418829.965]
# INFO: 2023-09-18 11:46:07,607 [SYNTHESIZER] - Sample segment (418829.965, 448746.391]
# INFO: 2023-09-18 11:46:10,810 [SYNTHESIZER] - Sample segment (448746.391, 478662.817]
# INFO: 2023-09-18 11:46:13,934 [SYNTHESIZER] - Sample segment (478662.817, 508579.243]
# INFO: 2023-09-18 11:46:17,134 [SYNTHESIZER] - Sample segment (508579.243, 538495.67]
# INFO: 2023-09-18 11:46:20,324 [SYNTHESIZER] - Sample segment (538495.67, 568412.096]
# INFO: 2023-09-18 11:46:23,739 [SYNTHESIZER] - Sample segment (568412.096, 598328.522]
# INFO: 2023-09-18 11:46:26,966 [SYNTHESIZER] - Sample segment (598328.522, 628244.948]
# INFO: 2023-09-18 11:46:30,140 [SYNTHESIZER] - Sample segment (628244.948, 658161.374]
# INFO: 2023-09-18 11:46:33,380 [SYNTHESIZER] - Sample segment (658161.374, 688077.8]
# INFO: 2023-09-18 11:46:36,797 [SYNTHESIZER] - Sample segment (688077.8, 717994.226]
# INFO: 2023-09-18 11:46:39,961 [SYNTHESIZER] - Sample segment (717994.226, 747910.652]
# INFO: 2023-09-18 11:46:43,216 [SYNTHESIZER] - Sample segment (747910.652, 777827.078]
# INFO: 2023-09-18 11:46:46,406 [SYNTHESIZER] - Sample segment (777827.078, 807743.504]
# INFO: 2023-09-18 11:46:49,496 [SYNTHESIZER] - Sample segment (807743.504, 837659.93]
# INFO: 2023-09-18 11:46:52,755 [SYNTHESIZER] - Sample segment (837659.93, 867576.357]
# INFO: 2023-09-18 11:46:55,919 [SYNTHESIZER] - Sample segment (867576.357, 897492.783]
# INFO: 2023-09-18 11:46:59,095 [SYNTHESIZER] - Sample segment (897492.783, 927409.209]
# INFO: 2023-09-18 11:47:02,349 [SYNTHESIZER] - Sample segment (927409.209, 957325.635]
# INFO: 2023-09-18 11:47:05,828 [SYNTHESIZER] - Sample segment (957325.635, 987242.061]
# INFO: 2023-09-18 11:47:09,107 [SYNTHESIZER] - Sample segment (987242.061, 1017158.487]
# INFO: 2023-09-18 11:47:12,354 [SYNTHESIZER] - Sample segment (1017158.487, 1047074.913]
# INFO: 2023-09-18 11:47:15,665 [SYNTHESIZER] - Sample segment (1047074.913, 1076991.339]
# INFO: 2023-09-18 11:47:19,187 [SYNTHESIZER] - Sample segment (1076991.339, 1106907.765]
# INFO: 2023-09-18 11:47:22,366 [SYNTHESIZER] - Sample segment (1106907.765, 1136824.191]
# INFO: 2023-09-18 11:47:25,690 [SYNTHESIZER] - Sample segment (1136824.191, 1166740.617]
# INFO: 2023-09-18 11:47:28,814 [SYNTHESIZER] - Sample segment (1166740.617, 1196657.043]
# INFO: 2023-09-18 11:47:32,096 [SYNTHESIZER] - Sample segment (1196657.043, 1226573.47]
# INFO: 2023-09-18 11:47:35,250 [SYNTHESIZER] - Sample segment (1226573.47, 1256489.896]
# INFO: 2023-09-18 11:47:38,528 [SYNTHESIZER] - Sample segment (1256489.896, 1286406.322]
# INFO: 2023-09-18 11:47:41,641 [SYNTHESIZER] - Sample segment (1286406.322, 1316322.748]
# INFO: 2023-09-18 11:47:44,855 [SYNTHESIZER] - Sample segment (1316322.748, 1346239.174]
# INFO: 2023-09-18 11:47:48,219 [SYNTHESIZER] - Sample segment (1346239.174, 1376155.6]
# INFO: 2023-09-18 11:47:51,495 [SYNTHESIZER] - Sample segment (1376155.6, 1406072.026]
# INFO: 2023-09-18 11:47:54,683 [SYNTHESIZER] - Sample segment (1406072.026, 1435988.452]
# INFO: 2023-09-18 11:47:57,938 [SYNTHESIZER] - Sample segment (1435988.452, 1465904.878]
# INFO: 2023-09-18 11:48:01,269 [SYNTHESIZER] - Sample segment (1465904.878, 1495821.304]
# INFO: 2023-09-18 11:48:04,407 [SYNTHESIZER] - Sample segment (1495821.304, 1525737.73]
# INFO: 2023-09-18 11:48:07,659 [SYNTHESIZER] - Sample segment (1525737.73, 1555654.157]
# INFO: 2023-09-18 11:48:10,827 [SYNTHESIZER] - Sample segment (1555654.157, 1585570.583]
# INFO: 2023-09-18 11:48:14,147 [SYNTHESIZER] - Sample segment (1585570.583, 1615487.009]
# INFO: 2023-09-18 11:48:17,408 [SYNTHESIZER] - Sample segment (1615487.009, 1645403.435]
# INFO: 2023-09-18 11:48:20,666 [SYNTHESIZER] - Sample segment (1645403.435, 1675319.861]
# INFO: 2023-09-18 11:48:24,129 [SYNTHESIZER] - Sample segment (1675319.861, 1705236.287]
# INFO: 2023-09-18 11:48:27,228 [SYNTHESIZER] - Sample segment (1705236.287, 1735152.713]
# INFO: 2023-09-18 11:48:30,238 [SYNTHESIZER] - Sample segment (1735152.713, 1765069.139]
# INFO: 2023-09-18 11:48:33,433 [SYNTHESIZER] - Sample segment (1765069.139, 1794985.565]
# INFO: 2023-09-18 11:48:36,585 [SYNTHESIZER] - Sample segment (1794985.565, 1824901.991]
# INFO: 2023-09-18 11:48:39,808 [SYNTHESIZER] - Sample segment (1824901.991, 1854818.417]
# INFO: 2023-09-18 11:48:43,132 [SYNTHESIZER] - Sample segment (1854818.417, 1884734.843]
# INFO: 2023-09-18 11:48:46,351 [SYNTHESIZER] - Sample segment (1884734.843, 1914651.27]
# INFO: 2023-09-18 11:48:49,686 [SYNTHESIZER] - Sample segment (1914651.27, 1944567.696]
# INFO: 2023-09-18 11:48:52,914 [SYNTHESIZER] - Sample segment (1944567.696, 1974484.122]
# INFO: 2023-09-18 11:48:56,329 [SYNTHESIZER] - Sample segment (1974484.122, 2004400.548]
# INFO: 2023-09-18 11:48:59,677 [SYNTHESIZER] - Sample segment (2004400.548, 2034316.974]
# INFO: 2023-09-18 11:49:02,827 [SYNTHESIZER] - Sample segment (2034316.974, 2064233.4]
# INFO: 2023-09-18 11:49:06,100 [SYNTHESIZER] - Sample segment (2064233.4, 2094149.826]
# INFO: 2023-09-18 11:49:09,382 [SYNTHESIZER] - Sample segment (2094149.826, 2124066.252]
# INFO: 2023-09-18 11:49:12,624 [SYNTHESIZER] - Sample segment (2124066.252, 2153982.678]
# INFO: 2023-09-18 11:49:15,869 [SYNTHESIZER] - Sample segment (2153982.678, 2183899.104]
# INFO: 2023-09-18 11:49:19,195 [SYNTHESIZER] - Sample segment (2183899.104, 2213815.53]
# INFO: 2023-09-18 11:49:22,235 [SYNTHESIZER] - Sample segment (2213815.53, 2243731.957]
# INFO: 2023-09-18 11:49:25,545 [SYNTHESIZER] - Sample segment (2243731.957, 2273648.383]
# INFO: 2023-09-18 11:49:28,657 [SYNTHESIZER] - Sample segment (2273648.383, 2303564.809]
# INFO: 2023-09-18 11:49:31,917 [SYNTHESIZER] - Sample segment (2303564.809, 2333481.235]
# INFO: 2023-09-18 11:49:35,271 [SYNTHESIZER] - Sample segment (2333481.235, 2363397.661]
# INFO: 2023-09-18 11:49:38,548 [SYNTHESIZER] - Sample segment (2363397.661, 2393314.087]
# INFO: 2023-09-18 11:49:41,781 [SYNTHESIZER] - Sample segment (2393314.087, 2423230.513]
# INFO: 2023-09-18 11:49:45,093 [SYNTHESIZER] - Sample segment (2423230.513, 2453146.939]
# INFO: 2023-09-18 11:49:48,328 [SYNTHESIZER] - Sample segment (2453146.939, 2483063.365]
# INFO: 2023-09-18 11:49:51,478 [SYNTHESIZER] - Sample segment (2483063.365, 2512979.791]
# INFO: 2023-09-18 11:49:54,698 [SYNTHESIZER] - Sample segment (2512979.791, 2542896.217]
# INFO: 2023-09-18 11:49:58,067 [SYNTHESIZER] - Sample segment (2542896.217, 2572812.643]
# INFO: 2023-09-18 11:50:01,381 [SYNTHESIZER] - Sample segment (2572812.643, 2602729.07]
# INFO: 2023-09-18 11:50:04,574 [SYNTHESIZER] - Sample segment (2602729.07, 2632645.496]
# INFO: 2023-09-18 11:50:07,805 [SYNTHESIZER] - Sample segment (2632645.496, 2662561.922]
# INFO: 2023-09-18 11:50:11,020 [SYNTHESIZER] - Sample segment (2662561.922, 2692478.348]
# INFO: 2023-09-18 11:50:14,447 [SYNTHESIZER] - Sample segment (2692478.348, 2722394.774]
# INFO: 2023-09-18 11:50:17,640 [SYNTHESIZER] - Sample segment (2722394.774, 2752311.2]
# INFO: 2023-09-18 11:50:20,899 [SYNTHESIZER] - Sample segment (2752311.2, 2782227.626]
# INFO: 2023-09-18 11:50:24,339 [SYNTHESIZER] - Sample segment (2782227.626, 2812144.052]
# INFO: 2023-09-18 11:50:27,510 [SYNTHESIZER] - Sample segment (2812144.052, 2842060.478]
# INFO: 2023-09-18 11:50:30,794 [SYNTHESIZER] - Sample segment (2842060.478, 2871976.904]
# INFO: 2023-09-18 11:50:34,079 [SYNTHESIZER] - Sample segment (2871976.904, 2901893.33]
# INFO: 2023-09-18 11:50:37,249 [SYNTHESIZER] - Sample segment (2901893.33, 2931809.757]
# INFO: 2023-09-18 11:50:40,345 [SYNTHESIZER] - Sample segment (2931809.757, 2961726.183]
# INFO: 2023-09-18 11:50:43,620 [SYNTHESIZER] - Sample segment (2961726.183, 2991642.609]
# INFO: 2023-09-18 11:50:46,827 [SYNTHESIZER] - Sample segment (2991642.609, 3021559.035]
# INFO: 2023-09-18 11:50:50,084 [SYNTHESIZER] - Sample segment (3021559.035, 3051475.461]
# INFO: 2023-09-18 11:50:53,390 [SYNTHESIZER] - Sample segment (3051475.461, 3081391.887]
# INFO: 2023-09-18 11:50:56,722 [SYNTHESIZER] - Sample segment (3081391.887, 3111308.313]
# INFO: 2023-09-18 11:50:59,881 [SYNTHESIZER] - Sample segment (3111308.313, 3141224.739]
# INFO: 2023-09-18 11:51:03,196 [SYNTHESIZER] - Sample segment (3141224.739, 3171141.165]
# INFO: 2023-09-18 11:51:06,379 [SYNTHESIZER] - Sample segment (3171141.165, 3201057.591]
# INFO: 2023-09-18 11:51:09,743 [SYNTHESIZER] - Sample segment (3201057.591, 3230974.017]
# INFO: 2023-09-18 11:51:13,012 [SYNTHESIZER] - Sample segment (3230974.017, 3260890.443]
# INFO: 2023-09-18 11:51:16,087 [SYNTHESIZER] - Sample segment (3260890.443, 3290806.87]
# INFO: 2023-09-18 11:51:19,275 [SYNTHESIZER] - Sample segment (3290806.87, 3320723.296]
# INFO: 2023-09-18 11:51:22,653 [SYNTHESIZER] - Sample segment (3320723.296, 3350639.722]
# INFO: 2023-09-18 11:51:25,868 [SYNTHESIZER] - Sample segment (3350639.722, 3380556.148]
# INFO: 2023-09-18 11:51:29,036 [SYNTHESIZER] - Sample segment (3380556.148, 3410472.574]
# INFO: 2023-09-18 11:51:32,512 [SYNTHESIZER] - Sample segment (3410472.574, 3440389.0]

# %%
# The synthesized dataset
synth.head(10)
# Out:
#    time   action     amount     nameOrig     nameDest  isFraud
# 0     1  CASH_IN  122791.96  C9591120449  M6409786995        0
# 1     1  CASH_IN   79803.09  C5807801908  M5755289891        0
# 2     2  CASH_IN  156840.43  C1334878977  M3415753055        0
# 3     3  CASH_IN  193313.32  C3740910264  M8567191626        0
# 4     4  CASH_IN  194787.86  C4657496587  M2354907092        0
# 5     5  CASH_IN  116975.32  C4748537470  M4552265961        0
# 6     7  CASH_IN  232024.15  C5761956747  M9666450213        0
# 7     7  CASH_IN   12429.11  C2392540098  M6105363121        0
# 8     8  CASH_IN  207648.52  C6610491152  M0094956430        0
# 9     9  CASH_IN  107426.96  C9879300551  M3042571398        0

# %%
# Saving to .csv
from ydata.connectors import LocalConnector
from ydata.connectors.filetype import FileType

conn = LocalConnector()
conn.write_file(synth, 'data/new_synth_sample.csv', file_type=FileType.CSV)

# %% [markdown]
# ### Calculating the constrained features - balances

# %% [markdown]
# To get a full replica, we need to re-add the balances and overdraft flags following the business logic described above. It's a matter of keeping a global per-entity state of the balance and, for every transaction:
# - verifying whether it's an overdraft
# - update the old and new balances of the origin and destination entities according to the transaction type
#
# The function `calculate_balance_with_interactions` does just that. It contains a fundamental assumption: the starting balance of all entities is zero. For specific use cases, this assumption could be tweaked - as it will probably not hold true in most real life scenarios.
#
# The business logic expressed in this function could also be changed to, for instance, test new hypothesis while guaranteeing the distribution of transaction amounts and types is kept.

# %%
#from utils import calculate_balance_with_interactions
import pandas as pd
# %run utils.py

pd_synth = synth.to_pandas()
balances = calculate_balance_with_interactions(pd_synth)

# %% [markdown]
# Let's join the two dataframes and have a **new dataset combining smart synthetic data with precise business logic for balance calculation**:

# %%
full_synth = pd.concat([pd_synth, balances], axis=1)
full_synth.head()
# Out:
#    time   action     amount     nameOrig     nameDest  isFraud  \
# 0     1  CASH_IN  122791.96  C9591120449  M6409786995        0
# 1     1  CASH_IN   79803.09  C5807801908  M5755289891        0
# 2     2  CASH_IN  156840.43  C1334878977  M3415753055        0
# 3     3  CASH_IN  193313.32  C3740910264  M8567191626        0
# 4     4  CASH_IN  194787.86  C4657496587  M2354907092        0
#
#    oldBalanceOrig  newBalanceOrig  oldBalanceDest  newBalanceDest  \
# 0             0.0       122791.96             0.0             0.0
# 1             0.0        79803.09             0.0             0.0
# 2             0.0       156840.43             0.0             0.0
# 3             0.0       193313.32             0.0             0.0
# 4             0.0       194787.86             0.0             0.0
#
#    isUnauthorizedOverdraft
# 0                        0
# 1                        0
# 2                        0
# 3                        0
# 4                        0

# %%
from ydata.connectors import LocalConnector
from ydata.connectors.filetype import FileType

conn = LocalConnector()
conn.write_file(full_synth, 'data/new_synth_sample_with_balances.csv', file_type=FileType.CSV)

# %% [markdown]
# ## Evaluating the quality of the synthetic dataset

# %%
#import pandas as pd
#full_synth = pd.read_csv("data/new_synth_sample_with_balances.csv")

# %% [markdown]
# For the dataset to be useful in use cases such as data sharing (for testing), it needs to show the same statistical fidelity, coherence and abidance by business logic. Let's verify that.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(font_scale=1.5)
sns.set_theme(style="whitegrid", rc={"axes.labelcolor": '#7A7A7A', "font.size": 12, "figure.titlesize": 16, "axes.labelsize": 12})
REAL_COLOR = '#474747'
SYNTH_COLOR = '#E32212'
# Out:
# INFO: 2023-09-18 12:21:35,780 generated new fontManager

# %% [markdown]
# **Shape and data types**

# %%
original = dataset.to_pandas()
full_synth = full_synth[original.columns.tolist()] # re-ordering columns

# %%
print(original.dtypes, '\n\n', full_synth.dtypes)
# Out:
# time                         int64
# action                      string
# amount                     float64
# nameOrig                    string
# oldBalanceOrig             float64
# newBalanceOrig             float64
# nameDest                    string
# oldBalanceDest             float64
# newBalanceDest             float64
# isFraud                      int64
# isUnauthorizedOverdraft      int64
# dtype: object
#
#  time                         int64
# action                      string
# amount                     float64
# nameOrig                    string
# oldBalanceOrig             float64
# newBalanceOrig             float64
# nameDest                    string
# oldBalanceDest             float64
# newBalanceDest             float64
# isFraud                      int64
# isUnauthorizedOverdraft      int64
# dtype: object

# %%
print(original.shape, full_synth.shape)
# Out:
# (3440390, 11) (3440390, 11)

# %% [markdown]
# As expected, the shapes and data types of both datasets match.

# %% [markdown]
# **Types of transactions**

# %%
original_ops = original.action.value_counts()
synth_ops = full_synth.action.value_counts()

ops_data = {
    'Data': len(original_ops) * ['Original'] + len(original_ops) * ['Synthetic'],
    'Transaction': original_ops.index.tolist() + synth_ops.index.tolist(),
    'Count': list(original_ops.values) + list(synth_ops.values)
}
ops_df = pd.DataFrame(ops_data)

# %%
fig, ax = plt.subplots(figsize=[11, 8])
b=sns.barplot(data=ops_df,
            y='Transaction',
            x='Count',
            hue='Data',
            orient='h',
            ax=ax,
            palette=[REAL_COLOR, SYNTH_COLOR],
            alpha=1.0,
            )
b.set_xscale("log")
fig.suptitle("Transactions per type in real and synthetic datasets")
ax.set_xlabel("Number of transactions (logarithmic scale)")
ax.set_ylabel("Type")
plt.legend(loc='lower right')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Number of unique origin entities (customers)**

# %% [markdown]
# As the only origin entity we have is _Customers_, we can just compare the number of unique origin entities between the two datasets.

# %%
len(original.nameOrig.unique())
# Out:
# 20755

# %%
len(full_synth.nameOrig.unique())
# Out:
# 20541

# %% [markdown]
# **Number of unique destination entities (customers, merchants, banks)**

# %% [markdown]
# For destination entities (which can be _Customers_, _Merchants_ or _Banks_), we need to visualize:

# %%
original_banks = len(original[original.nameDest.str[0] == 'B'].nameDest.unique())
original_customers = len(original[original.nameDest.str[0] == 'C'].nameDest.unique())
original_merchants = len(original[original.nameDest.str[0] == 'M'].nameDest.unique())
synth_banks = len(full_synth[full_synth.nameDest.str[0] == 'B'].nameDest.unique())
synth_customers = len(full_synth[full_synth.nameDest.str[0] == 'C'].nameDest.unique())
synth_merchants = len(full_synth[full_synth.nameDest.str[0] == 'M'].nameDest.unique())

dest_data = {
    'Data': 3 * ['Original'] + 3 * ['Synthetic'] ,
    'Entity': ['Banks', 'Customers', 'Merchants'] * 2,
    'Count': [original_banks, original_customers, original_merchants, synth_banks, synth_customers, synth_merchants]
}

dest_df = pd.DataFrame(dest_data)

# %%
fig, ax = plt.subplots(figsize=[11, 8])
b=sns.barplot(data=dest_df,
            y='Entity',
            x='Count',
            hue='Data',
            orient='h',
            ax=ax,
            palette=[REAL_COLOR, SYNTH_COLOR],
            alpha=1.0,
            )
b.set_xscale("log")
fig.suptitle("Unique destination entities in real and synthetic datasets")
ax.set_ylabel("Entity type")
ax.set_xlabel("Number of entities (logarithmic scale)")
plt.tight_layout()
plt.show()

# %% [markdown]
# **Fraudulent events**

# %%
original_fraud = original[original.isFraud == 1].action.value_counts()
synth_fraud = full_synth[original.isFraud==1].action.value_counts()

fraud_data = {
    'Data': len(original_fraud) * ['Original'] + len(synth_fraud) * ['Synthetic'],
    'Type': original_fraud.index.tolist() + synth_fraud.index.tolist(),
    'Count': list(original_fraud.values) + list(synth_fraud.values)
}
fraud_df = pd.DataFrame(fraud_data)

# %%
fig, ax = plt.subplots(figsize=[11, 8])
b=sns.barplot(data=fraud_df,
            y='Type',
            x='Count',
            hue='Data',
            orient='h',
            ax=ax,
            palette=[REAL_COLOR, SYNTH_COLOR],
            alpha=1.0,
            )
#b.set_xscale("log")
#ax.set_xlim([0, 17])
fig.suptitle("Number of fraudulent events per transaction type in real and synthetic datasets")
ax.set_xlabel("Number of events")
ax.set_ylabel("Transaction type")
plt.legend(loc='lower right')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Unauthorized overdraft**

# %%
original_over = original[original.isUnauthorizedOverdraft == 1].action.value_counts()
synth_over = full_synth[original.isUnauthorizedOverdraft==1].action.value_counts()

over_data = {
    'Data': len(original_over) * ['Original'] + len(synth_over) * ['Synthetic'],
    'Type': original_over.index.tolist() + synth_over.index.tolist(),
    'Count': list(original_over.values) + list(synth_over.values)
}
over_df = pd.DataFrame(over_data)

# %%
fig, ax = plt.subplots(figsize=[11, 8])
b=sns.barplot(data=over_df,
            y='Type',
            x='Count',
            hue='Data',
            orient='h',
            ax=ax,
            palette=[REAL_COLOR, SYNTH_COLOR],
            alpha=1.0,
            )
b.set_xscale("log")
fig.suptitle("Number of overdraft events per transaction type in real and synthetic datasets")
ax.set_xlabel("Number of events (logarithmic scale)")
ax.set_ylabel("Transaction type")
plt.tight_layout()
plt.show()

# %% [markdown]
# **Distribution of transactions' amounts**

# %%
fig, ax = plt.subplots(figsize=(25, 10))
sns.histplot(data=original, x='amount' , color=REAL_COLOR, label='Original', bins=100, alpha=0.5, ax=ax)
sns.histplot(data=full_synth, x='amount' , color=SYNTH_COLOR, label='Synthetic', bins=100, alpha=0.5, ax=ax)
fig.suptitle("Distribution of transaction amounts for real and synthetic data")
ax.set_xlabel("Amount (binned")
ax.set_ylabel("Count (logarithmic scale)")
ax.set_yscale('log')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# **Distribution of balances (origin entities)**

# %%
fig, ax = plt.subplots(figsize=(25, 10))
sns.histplot(data=original, x='newBalanceOrig' , color=REAL_COLOR, label='Original', bins=100, alpha=0.5, ax=ax)
sns.histplot(data=full_synth, x='newBalanceOrig' , color=SYNTH_COLOR, label='Synthetic', bins=100, alpha=0.5, ax=ax)
fig.suptitle("Distribution of balances from the origin entities for real and synthetic data")
ax.set_xlabel("Balance (binned")
ax.set_ylabel("Count (logarithmic scale)")
ax.set_yscale('log')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# This lighter color means overlap.

# %% [markdown]
# **Distribution of balances (destination entities)**

# %% [markdown]
# We need to separate by type of entity, as they have very different behaviours.

# %%
fig, axs = plt.subplots(3,1, figsize=(25, 30))
axs.flatten()

for idx, e in enumerate(['C', 'M', 'B']):
    ax = axs[idx]
    sns.histplot(data=original[original.nameDest.str[0] == e], x='newBalanceDest' , color=REAL_COLOR, label='Original', bins=100, alpha=0.5, ax=ax)
    sns.histplot(data=full_synth[full_synth.nameDest.str[0] == e], x='newBalanceDest' ,color=SYNTH_COLOR, label='Synthetic', bins=100, alpha=0.5, ax=ax)
    ax.set_title("Entity = {}".format(e))
    ax.set_xlabel("Balance (binned)")
    ax.set_ylabel("Count (logarithmic scale)")
    ax.set_yscale('log')

plt.legend()
fig.suptitle("Distribution of balances from the destination entities for real and synthetic data \n (Merchant, Bank, Customer entities)")
#plt.tight_layout()
plt.show()

# %% [markdown]
# Banks, as expected, always keep their balances in 0.

# %% [markdown]
# **Evolution over time of the balances of the destination entities**

# %% [markdown]
# To understand the evolution over time of the banking system we are simulating, let's now take a look at the **overall behaviour of the destination entities**. Let's analyze the cumulative sum of their balances, to try to understand if, regardless of the specific entities and transaction types, the overall mass of money in the destination end is constant:

# %%
fig, ax = plt.subplots(1,1, figsize=(25,8))
COLORS = [REAL_COLOR, SYNTH_COLOR]
LABELS = ['Original', 'Synthetic']

for idx, d in enumerate([original, full_synth]):
    cumsum = d.newBalanceDest.cumsum()
    time = d.time
    ax.plot(time, cumsum, label=LABELS[idx], color=COLORS[idx], linewidth=5)
    ax.fill_between(time, 0, cumsum, facecolor=COLORS[idx], alpha=0.5)
    del(cumsum, time)

ax.set_xlabel("Time")
ax.set_ylabel("Cumulative sum of the balances of the destination entities")
plt.legend()
plt.show()

# %% [markdown]
# Filtered for _Customers_, _Merchants_ and _Banks_ and the behaviour is exactly the same.

# %% [markdown]
# **Revalidation of business constraints**

# %% [markdown]
# We can reuse our Constraints and build a new Constraints Engine on the synthetic dataset to check if the new data is following our pre-defined business rules.

# %%
synth_engine = ConstraintEngine()
synth_engine.add_constraints([c1, c2, c3, c4])
synth_engine.validate(Dataset(full_synth))

# %%
synth_engine.summary()
# Out:
# {'rows_violation_count': 3429852,
#  'rows_violation_ratio': 0.9969369751685129,
#  'violation_per_constraint': {"Positive(columns=['amount'])": {'rows_violation_count': 3429852,
#    'rows_violation_ratio': 0.9969369751685129,
#    'validation_time': 0.99},
#   'Validate type of origin entity | axis=0': {'rows_violation_count': 0,
#    'rows_violation_ratio': 0.0,
#    'validation_time': 4.53},
#   'Validate overdraft behaviour | axis=1': {'rows_violation_count': 0,
#    'rows_violation_ratio': 0.0,
#    'validation_time': 50.16},
#   'Balances updates coherence | axis=1': {'rows_violation_count': 0,
#    'rows_violation_ratio': 0.0,
#    'validation_time': 234.66}}}

# %% [markdown]
# ## Wrap-up

# %% [markdown]
# _For optimal results, synthesizing data must be a balancing act between leveraging data-driven state-of-the-art algorithms and infusing the process with domain-specific knowledge. YData recognizes that and builds its entire SDK so that it's possible to get the best of both worlds._
