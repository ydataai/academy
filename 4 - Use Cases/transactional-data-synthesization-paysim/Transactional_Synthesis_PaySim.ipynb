# %% [markdown]
# # Using YData to synthesize sequential transactional data
#
# ## Context
#
# Payments data is one of the most common types of transactional datasets, and for many business areas one of the most valuable. However, it is particularly sensitive and has complex underlying logic governing it, which makes it a perfect test bed for data quality assessment and synthetic data generation.
#
# The dataset _“PaySim: A financial mobile money simulator for fraud detection”_ is a case study based on a real company that developed a mobile money implementation which provided mobile phone users the ability to transfer money between themselves using the phone as a sort of electronic wallet.

# %% [markdown]
# **Outline of this document**
#
# - Ingesting and understanding a transactional financial dataset, including abidance by business logic
# - Training a synthetic data generator over the dataset
# - Generating a synthetic version of the dataset, integrating the aforementioned business logic
# - Evaluating the statistical fidelity and coherence of the generated data

# %% [markdown]
# ## Dataset: PaySim

# %% [markdown]
# PaySim simulates mobile money transactions based on a sample of real transactions (extracted from one month of financial logs from a mobile money service implemented in an African country). The original logs were provided by a multinational company, who is the provider of a mobile financial service currently running in more than 14 countries all around the world.
#
# The PaySim version used is a custom one generated through the code on the [PaySim GitHub repository](https://github.com/EdgarLopezPhD/PaySim) and based on the paper [_PaySim: A financial mobile money simulator for fraud detection_](https://www.researchgate.net/publication/313138956_PAYSIM_A_FINANCIAL_MOBILE_MONEY_SIMULATOR_FOR_FRAUD_DETECTION).

# %% [markdown]
# ### Loading the dataset
#
# YData's platform is fully integrated - this means that any source of data created through the UI can be easily consumed within the Labs (via the [Platform SDK](https://github.com/ydataai/academy/blob/master/1%20-%20platform-sdk/ui-to-sdk-examples.ipynb)) for further exploration, leveraging the platform's built-in scalability. Alternatively, YData's [Connectors](https://github.com/ydataai/academy/tree/master/2%20-%20connectors) could also be used.
#
# Below, the Platform SDK will be used.

# %%
# %pip install --no-dependencies --force ydata_utils-0.0.0-py2.py3-none-any.whl
# %pip install --no-dependencies --force ydata_synthesizers-0.0.0-py2.py3-none-any.whl
# Out:
# Processing ./ydata_utils-0.0.0-py2.py3-none-any.whl
# Installing collected packages: ydata-utils
#   Attempting uninstall: ydata-utils
#     Found existing installation: ydata-utils 0.0.0
#     Uninstalling ydata-utils-0.0.0:
#       Successfully uninstalled ydata-utils-0.0.0
# Successfully installed ydata-utils-0.0.0
# Note: you may need to restart the kernel to use updated packages.
# Processing ./ydata_synthesizers-0.0.0-py2.py3-none-any.whl
# Installing collected packages: ydata-synthesizers
#   Attempting uninstall: ydata-synthesizers
#     Found existing installation: ydata-synthesizers 0.0.0
#     Uninstalling ydata-synthesizers-0.0.0:
#       Successfully uninstalled ydata-synthesizers-0.0.0
# Successfully installed ydata-synthesizers-0.0.0
# Note: you may need to restart the kernel to use updated packages.

# %% [raw]
# # Importing YData's packages
# from ydata.platform.datasources import DataSources
# from ydata.metadata import Metadata
# from ydata.dataset import Dataset
#
# # Creating a Dataset from the Data Source
# datasource = DataSources.get(uid='fe9e35ba-17bd-4dd4-b2d5-844764323028', namespace='d134e271-5e3c-4f32-a657-ee6ce8936820')
# dataset = datasource.read()
#
# # Quickly previewing the Dataset
# dataset.head()

# %%
import pandas as pd
df = pd.read_csv('paysim.xls')

# %%
from ydata.dataset import Dataset

dataset = Dataset(df)

# %%
dataset.shape(lazy_eval=False)
# Out:
# (3440390, 13)

# %%
dataset.value_counts(col='isUnauthorizedOverdraft')
# Out:
# 0    3382697
# 1      57693
# Name: isUnauthorizedOverdraft, dtype: int64

# %%
dataset.value_counts(col='isFraud')
# Out:
# 0    3439000
# 1       1390
# Name: isFraud, dtype: int64

# %%
dataset.value_counts(col='isFlaggedFraud')
# Out:
# 0    3440390
# Name: isFlaggedFraud, dtype: int64

# %%
dataset.uniques('action')
# Out:
# 5

# %% [markdown]
# From this quick peek at the dataset, we can identify several things:
#
# - about 3.4 million transactions
# - `time` is our sequential indicator (`step` represents an hour of transactions, `time` is a linear indicator of the transaction order)
# - existing features:
#     - features describing the financial operation and its flow (`type`, `amount`, `nameOrig` and `nameDest`)
#     - features keeping track of the balance of each financial entity (`oldbalanceDest`, `newbalanceDest`, `oldbalanceOrg`, `newbalanceOrig`)
#     - features related with fraud (`isFlaggedFraud`, automatically detected potential frauds and `isFraud`, the real assessment).
# - 5 types of financial transactions: `CASH_IN`, `CASH_OUT`, `PAYMENT`, `TRANSFER`, `DEBIT` (ordered by decreasing relative frequency)
# - the existance of `isUnauthorizedOverdraft` events due to lack of funds (~1.67% of all transactions)
# - the existence of fraudulent events in `isFraud`, with the dataset revealing a huge imbalance: only ~0.04% of all transactions were fraudulent
#   - the `isFlaggedFraud` column is the result of a naive rule automatically flaggging transfers above 200k. This dataset in particular contains no such events.

# %% [markdown]
# ### Evaluating data quality

# %% [markdown]
# The automated profiling available on the platform heavily complements these insights above with univariante and multivariate profiling plus automatic detection of potential data quality issues. To access these data quality warnigs, useful to identify potential issues which must be solved prior to data synthesis, a `Metadata` object, holding information about the dataset, must be created.

# %%
from ydata.metadata import Metadata
# Creating a Metadata (where warnings can be reviewed) from the Dataset
metadata = Metadata(dataset)
print(metadata)
# Out:
# [########################################] | 100% Completed | 215.84 ms
# [########################################] | 100% Completed | 17.92 ss
# [                                        ] | 0% Completed | 182.83 us
# /home/ydata/.venv/lib/python3.10/site-packages/dask/array/core.py:4917: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# [########################################] | 100% Completed | 33.06 ss
# Metadata Summary
#
# Dataset type: TABULAR
# Dataset attributes:
# Number of columns: 13
# Number of rows: 3440390
# Duplicate rows: 0
# Target column:
#
# Column detail:
#                      Column    Data type Variable type Characteristics
# 0                      time    numerical           int
# 1                      step    numerical           int
# 2                    action  categorical        string
# 3                    amount    numerical         float
# 4                  nameOrig       string        string
# 5            oldBalanceOrig    numerical         float
# 6            newBalanceOrig    numerical         float
# 7                  nameDest       string        string
# 8            oldBalanceDest    numerical         float
# 9            newBalanceDest    numerical         float
# 10                  isFraud  categorical           int
# 11           isFlaggedFraud  categorical           int
# 12  isUnauthorizedOverdraft  categorical           int
#
# Warnings:
#        Warning                                                                                                                                                                                                                                      Columns
# 0     skewness                                                                                                                                                               [step, amount, oldBalanceOrig, newBalanceOrig, oldBalanceDest, newBalanceDest]
# 1  cardinality                                                                                                                                                                                                                         [nameOrig, nameDest]
# 2     constant                                                                                                                                                                                                                             [isFlaggedFraud]
# 3        zeros                                                                                                                                                                       [time, oldBalanceOrig, newBalanceOrig, oldBalanceDest, newBalanceDest]
# 4  correlation  [time|step, time|oldBalanceDest, time|newBalanceDest, step|oldBalanceDest, step|newBalanceDest, action|amount, action|nameDest, action|oldBalanceDest, action|newBalanceDest, oldBalanceOrig|newBalanceOrig, oldBalanceDest|newBalanceDest]
# 5    imbalance                                                                                                                                                                                                   [action, isFraud, isUnauthorizedOverdraft]

# %% [markdown]
# This gives us additional information about the dataset: balances and amounts have highly skewed distributions, which suggests different transactions and client profiles. We also seem to have a large number of entities represented in this dataset, judging by the high cardinality warnings in our origin and destination entities.
#
# On the other hand, we see no issues with high missingness of values or duplicates. For now, we will drop the `step` column, as we have seen it encodes similar information as the `time` and explictly selec

# %%
dataset.drop_columns(['step', 'isFlaggedFraud'], inplace=True)

# %%
dataset.columns
# Out:
# ['time',
#  'action',
#  'amount',
#  'nameOrig',
#  'oldBalanceOrig',
#  'newBalanceOrig',
#  'nameDest',
#  'oldBalanceDest',
#  'newBalanceDest',
#  'isFraud',
#  'isUnauthorizedOverdraft']

# %% [markdown]
# ### Validation of business rules

# %% [markdown]
# A dataset not abiding by the expected business rules may silently go unnoticed through all the phases of a project and fail to deliver any business value when finally live. As such, it's important to validate these kind of constraints and business logic.
#
# YData's `ConstraintEngine` can be used for validation of several type of arbitrary row and column-wise constraints (per-entity, if required).

# %% [markdown]
# #### Which business rules and constraints does this dataset have?
#
# Stemming from its transactional-financial nature and given the [extra context available on Kaggle](https://www.kaggle.com/datasets/ealaxi/paysim1) and in the original paper, some implicit and explicit business rules can be derived for this dataset:
#
# - There are 3 different types of entities:
#     - _Banks_, which are always destination entities and whose balance is always 0
#     - _Customers_, which can be either origin or destination entities
#     - _Merchants_, which are always destination entities
# - Rejected overdraft operations (`isUnauthorizedOverdraft==1`), which can happen for all transaction types apart from `CASH_IN`, do not go through - the balances of both the origin and destination entity as kept.
# - Fraudulent events are an _a posteriori_ label, so all transactions marked as fraudulent (`isFraud == 1`) go through normally.
# - The `amount` column should only assume positive values (as the signal of the transaction depends on the `action`).
# - For every transaction and throughout time, the state of each entity (its balance) should be coherent with its interaction with other entities. This depends on the type of transaction:
#     - `CASH_IN`: always from _Customer_ to _Merchant_, with the origin balance increasing and the destination balance staying the same.
#     - `CASH_OUT`: always from _Customer_ to _Merchant_, with the origin balance decreasing and the destination balance staying the same.
#     - `PAYMENT`: always from _Customer_ to _Merchant_, with the origin balance decreasing and the destination balance increasing.
#     - `TRANSFER`: always from _Customer_ to _Customer_, with the origin balance decreasing and the destination balance increasing.
#     - `DEBIT`: always from _Customer_ to _Bank_, with the origin balance decreasing and the destination balance staying the same (0, as it is a _Bank_)
#
# Additionally, it's possible that the starting balances of some entities (_Customers_ or _Merchants_) are negative. YData's constraints engine allows us to express all this. Let's validate some of these.

# %%
from ydata.constraints.engine import ConstraintEngine
from ydata.constraints.rows import GreaterThan, Positive, CustomConstraint

# Create the custom constrains for the dataset

# Validate only customers (C) are origin entities and all destination entities are either Customers, Banks or Merchants
def validate_entities(df):
    return (df.nameOrig.str[0] == 'C') & (df.nameDest.str[0].isin(['C', 'B', 'M']))

# Validate what happens to the balances during a rejected overdraft
def validate_overdraft(r):
    if r.isUnauthorizedOverdraft == 1:
        if abs(r.newBalanceOrig-r.oldBalanceOrig) < 1e-6 and abs(r.newBalanceDest-r.oldBalanceDest) < 1e-6:
            return True
        else:
            return False
    else:
        return True

# Validate whether the balances are updated according to the operation type
def validate_interactions(r):

    ops_map = {
            'CASH_IN': [1, 0],
            'CASH_OUT': [-1, 0],
            'PAYMENT': [-1, 1],
            'TRANSFER': [-1, 1],
            'DEBIT': [-1, 0]
    }

    if r.isUnauthorizedOverdraft:
        return True # overdraft constraints are handled elsewhere

    op = r.action
    amount = r.amount

    try:
        assert abs(r.newBalanceOrig - (r.oldBalanceOrig + (amount*ops_map[op][0]))) <= 0.02
        assert abs(r.newBalanceDest - (r.oldBalanceDest + (amount*ops_map[op][1]))) <= 0.02
        return True
    except AssertionError:
        return False


# Some other out-of-the-box constrains are also available like GreaterThan,
# which checks whether a colum(n) is(are) greater than a certain provided value(s)

c1 = Positive(columns=['amount'])
c2 = CustomConstraint(name="Validate type of origin entity | axis=0",
                       check=validate_entities,
                       available_columns=['nameOrig', 'nameDest'],
                       axis=0)
c3 = CustomConstraint(name="Validate overdraft behaviour | axis=1",
                       check=validate_overdraft,
                       available_columns=['isUnauthorizedOverdraft', 'oldBalanceOrig', 'newBalanceOrig', 'oldBalanceDest', 'newBalanceDest'],
                       axis=1)

c4 = CustomConstraint(name="Balances updates coherence | axis=1",
                       check=validate_interactions,
                       available_columns=["isUnauthorizedOverdraft", "action", "amount", "oldBalanceOrig", "newBalanceOrig", "oldBalanceDest", "newBalanceDest"],
                       axis=1)

engine = ConstraintEngine()
engine.add_constraints([c1, c2, c3, c4])

# %% [markdown]
# #### Running the validation

# %%
# Getting the summary view of the constraints engine
engine.validate(dataset)
engine.summary()
# Out:
# /home/ydata/.venv/lib/python3.10/site-packages/ydata/dataset/dataset.py:80: UserWarning: All the input Variable Types were set as `string` or `object`. It is recommend to revise the VariableType settings for optimal results.
#   warnings.warn(
# /home/ydata/.venv/lib/python3.10/site-packages/dask/dataframe/core.py:6000: UserWarning:
# You did not provide metadata, so Dask is running your function on a small dataset to guess output types. It is possible that Dask will guess incorrectly.
# To provide an explicit output types or to silence this message, please provide the `meta=` keyword, as described in the map or apply function that you are using.
#   Before: .apply(func)
#   After:  .apply(func, meta=(None, 'bool'))
#
#   warnings.warn(meta_warning(meta))
# /home/ydata/.venv/lib/python3.10/site-packages/dask/dataframe/core.py:6000: UserWarning:
# You did not provide metadata, so Dask is running your function on a small dataset to guess output types. It is possible that Dask will guess incorrectly.
# To provide an explicit output types or to silence this message, please provide the `meta=` keyword, as described in the map or apply function that you are using.
#   Before: .apply(func)
#   After:  .apply(func, meta=(None, 'bool'))
#
#   warnings.warn(meta_warning(meta))
# {'rows_violation_count': 3429852,
#  'rows_violation_ratio': 0.9969369751685129,
#  'violation_per_constraint': {"Positive(columns=['amount'])": {'rows_violation_count': 3429852,
#    'rows_violation_ratio': 0.9969369751685129,
#    'validation_time': 0.66},
#   'Validate type of origin entity | axis=0': {'rows_violation_count': 0,
#    'rows_violation_ratio': 0.0,
#    'validation_time': 4.59},
#   'Validate overdraft behaviour | axis=1': {'rows_violation_count': 0,
#    'rows_violation_ratio': 0.0,
#    'validation_time': 48.86},
#   'Balances updates coherence | axis=1': {'rows_violation_count': 0,
#    'rows_violation_ratio': 0.0,
#    'validation_time': 226.19}}}

# %%
engine.summary()
# Out:
# {'rows_violation_count': 3429852,
#  'rows_violation_ratio': 0.9969369751685129,
#  'violation_per_constraint': {"Positive(columns=['amount'])": {'rows_violation_count': 3429852,
#    'rows_violation_ratio': 0.9969369751685129,
#    'validation_time': 0.66},
#   'Validate type of origin entity | axis=0': {'rows_violation_count': 0,
#    'rows_violation_ratio': 0.0,
#    'validation_time': 4.59},
#   'Validate overdraft behaviour | axis=1': {'rows_violation_count': 0,
#    'rows_violation_ratio': 0.0,
#    'validation_time': 48.86},
#   'Balances updates coherence | axis=1': {'rows_violation_count': 0,
#    'rows_violation_ratio': 0.0,
#    'validation_time': 226.19}}}

# %% [markdown]
# We can verify that, apart from the rounding error in transaction processing (quite significant, at 2 cents per transaction), the dataset is consistent with the identified business logic and does not show significant outliers.
#
# We can noew proceed to the synthesization step with renewed confidence. **The quality of a synthetic dataset is heavily influenced by the quality of the original dataset**. Thus, it becomes critical to first spend time understanding a dataset and identifying potential quality issues prior to synthesizing, before being surprised by new and unexpected behaviours inherited from the original data.

# %% [markdown]
# ## Creating a synthetic replica of the PaySim dataset

# %% [markdown]
# By now, it is clear that for each transaction, there is a lot of underlying logic governing the evolution of the balances and the interactions between entities. This needs to be taken into account while preparing a synthesis process.
#
# If we synthesize directly both the transaction amount and the balances, we are at risk of losing the coherence in the entity states across time, as we are not putting strict guarantees in place that their balances are correctly updated.
#
# As such, we can opt to **only synthesize the amounts and types of operations - guaranteeing those distributions mimick the original dataset - and manually reconstruct the balances after synthesization based on the business logic we described above**. Overdrafts also have a clear definition (when the amount surpasses the available balance), so we don't need to synthesize them - we can just detect and flag them during post-processing.

# %% [markdown]
# Based on our considerations above, we select the relevant variables for synthesis, by filtering out the balances and the rejected overdraft column. We **only synthesize the time, the type and amount of the transaction, the origin and destination entities and whether or not the transaction is fraudulent**.

# %%
#Selecting the columns to be synthesized

sel_dataset = dataset[['time',
                     'action',
                     'amount',
                     'nameOrig',
                     'nameDest',
                     'isFraud']]

# %% [markdown]
#  A `Metadata` object is where we configure all the settings for the synthetization. Let's create one to feed to our Synthesizers.
#
# For a multi-entity time series synthesizer, we need to indicate which columns define the sequential ordering and which specify the entities, so that our synthesized dataset presents per-entity sequentiality and coherence.

# %%
from ydata.utils.data_types import DataType, VariableType
from ydata.dataset.dataset_type import DatasetType
from ydata.synthesizers.timeseries.model import TimeSeriesSynthesizer

# Creating the Metadata object for the synthesis

dataset_attrs = {
     "sortbykey": "time",
     #"entities": ["nameOrig", "nameDest"]
}

m = Metadata(sel_dataset,
             dataset_attrs,
             dataset_type=DatasetType.TIMESERIES)
# Out:
# [########################################] | 100% Completed | 816.48 ms
# [########################################] | 100% Completed | 431.66 ms
# [########################################] | 100% Completed | 17.11 s
# [########################################] | 100% Completed | 14.33 ss

# %% [markdown]
# YData's `TimeSeriesSynthesizer` abstracts a lot of the complexity related with sequential data synthesis, by automatically selecting the best from a library of state-of-the-art models and orchestrating all the training. All via a simple interface. Training and sampling a Synthesizer takes, literally, 3 lines of code.

# %%
synthesizer = TimeSeriesSynthesizer()
synthesizer.fit(sel_dataset, metadata=m)
# Out:
# INFO: 2023-09-18 14:29:54,124 [SYNTHESIZER] - Initializing Time Series SYNTHESIZER.
# INFO: 2023-09-18 14:29:54,125 [SYNTHESIZER] - Number columns considered for synth: 6
# INFO: 2023-09-18 14:29:59,304 [SYNTHESIZER] - Starting the synthetic data modeling process over 115x1 blocks.
# INFO: 2023-09-18 14:29:59,305 [SYNTHESIZER] - Generating pipeline for segment (-0.001, 29916.426]
# INFO: 2023-09-18 14:29:59,313 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:29:59,323 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:29:59,324 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:30:07,981 [SYNTHESIZER] - Generating pipeline for segment (29916.426, 59832.852]
# INFO: 2023-09-18 14:30:07,985 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:30:07,992 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:30:07,993 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:30:16,660 [SYNTHESIZER] - Generating pipeline for segment (59832.852, 89749.278]
# INFO: 2023-09-18 14:30:16,665 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:30:16,672 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:30:16,672 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:30:24,820 [SYNTHESIZER] - Generating pipeline for segment (89749.278, 119665.704]
# INFO: 2023-09-18 14:30:24,825 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:30:24,832 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:30:24,833 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:30:33,358 [SYNTHESIZER] - Generating pipeline for segment (119665.704, 149582.13]
# INFO: 2023-09-18 14:30:33,362 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:30:33,369 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:30:33,371 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:30:42,065 [SYNTHESIZER] - Generating pipeline for segment (149582.13, 179498.557]
# INFO: 2023-09-18 14:30:42,070 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:30:42,077 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:30:42,078 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:30:50,566 [SYNTHESIZER] - Generating pipeline for segment (179498.557, 209414.983]
# INFO: 2023-09-18 14:30:50,571 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:30:50,578 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:30:50,579 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:30:59,127 [SYNTHESIZER] - Generating pipeline for segment (209414.983, 239331.409]
# INFO: 2023-09-18 14:30:59,132 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:30:59,139 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:30:59,139 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:31:07,745 [SYNTHESIZER] - Generating pipeline for segment (239331.409, 269247.835]
# INFO: 2023-09-18 14:31:07,750 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:31:07,757 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:31:07,758 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:31:16,152 [SYNTHESIZER] - Generating pipeline for segment (269247.835, 299164.261]
# INFO: 2023-09-18 14:31:16,157 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:31:16,164 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:31:16,165 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:31:24,642 [SYNTHESIZER] - Generating pipeline for segment (299164.261, 329080.687]
# INFO: 2023-09-18 14:31:24,648 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:31:24,655 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:31:24,656 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:31:33,149 [SYNTHESIZER] - Generating pipeline for segment (329080.687, 358997.113]
# INFO: 2023-09-18 14:31:33,154 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:31:33,161 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:31:33,162 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:31:41,610 [SYNTHESIZER] - Generating pipeline for segment (358997.113, 388913.539]
# INFO: 2023-09-18 14:31:41,615 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:31:41,622 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:31:41,623 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:31:50,503 [SYNTHESIZER] - Generating pipeline for segment (388913.539, 418829.965]
# INFO: 2023-09-18 14:31:50,508 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:31:50,514 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:31:50,515 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:31:58,566 [SYNTHESIZER] - Generating pipeline for segment (418829.965, 448746.391]
# INFO: 2023-09-18 14:31:58,570 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:31:58,577 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:31:58,578 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:32:06,899 [SYNTHESIZER] - Generating pipeline for segment (448746.391, 478662.817]
# INFO: 2023-09-18 14:32:06,903 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:32:06,910 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:32:06,911 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:32:15,268 [SYNTHESIZER] - Generating pipeline for segment (478662.817, 508579.243]
# INFO: 2023-09-18 14:32:15,273 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:32:15,280 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:32:15,281 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:32:23,966 [SYNTHESIZER] - Generating pipeline for segment (508579.243, 538495.67]
# INFO: 2023-09-18 14:32:23,971 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:32:23,978 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:32:23,979 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:32:32,481 [SYNTHESIZER] - Generating pipeline for segment (538495.67, 568412.096]
# INFO: 2023-09-18 14:32:32,486 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:32:32,492 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:32:32,493 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:32:41,351 [SYNTHESIZER] - Generating pipeline for segment (568412.096, 598328.522]
# INFO: 2023-09-18 14:32:41,356 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:32:41,363 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:32:41,363 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:32:50,052 [SYNTHESIZER] - Generating pipeline for segment (598328.522, 628244.948]
# INFO: 2023-09-18 14:32:50,057 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:32:50,064 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:32:50,065 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:32:58,498 [SYNTHESIZER] - Generating pipeline for segment (628244.948, 658161.374]
# INFO: 2023-09-18 14:32:58,503 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:32:58,510 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:32:58,511 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:33:07,139 [SYNTHESIZER] - Generating pipeline for segment (658161.374, 688077.8]
# INFO: 2023-09-18 14:33:07,145 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:33:07,152 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:33:07,152 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:33:15,875 [SYNTHESIZER] - Generating pipeline for segment (688077.8, 717994.226]
# INFO: 2023-09-18 14:33:15,880 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:33:15,887 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:33:15,888 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:33:24,478 [SYNTHESIZER] - Generating pipeline for segment (717994.226, 747910.652]
# INFO: 2023-09-18 14:33:24,483 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:33:24,490 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:33:24,491 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:33:33,132 [SYNTHESIZER] - Generating pipeline for segment (747910.652, 777827.078]
# INFO: 2023-09-18 14:33:33,137 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:33:33,144 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:33:33,145 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:33:41,918 [SYNTHESIZER] - Generating pipeline for segment (777827.078, 807743.504]
# INFO: 2023-09-18 14:33:41,923 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:33:41,930 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:33:41,930 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:33:50,892 [SYNTHESIZER] - Generating pipeline for segment (807743.504, 837659.93]
# INFO: 2023-09-18 14:33:50,897 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:33:50,904 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:33:50,905 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:33:59,478 [SYNTHESIZER] - Generating pipeline for segment (837659.93, 867576.357]
# INFO: 2023-09-18 14:33:59,483 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:33:59,490 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:33:59,490 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:34:08,224 [SYNTHESIZER] - Generating pipeline for segment (867576.357, 897492.783]
# INFO: 2023-09-18 14:34:08,229 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:34:08,236 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:34:08,237 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:34:17,034 [SYNTHESIZER] - Generating pipeline for segment (897492.783, 927409.209]
# INFO: 2023-09-18 14:34:17,039 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:34:17,045 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:34:17,047 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:34:25,717 [SYNTHESIZER] - Generating pipeline for segment (927409.209, 957325.635]
# INFO: 2023-09-18 14:34:25,722 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:34:25,729 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:34:25,730 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:34:34,664 [SYNTHESIZER] - Generating pipeline for segment (957325.635, 987242.061]
# INFO: 2023-09-18 14:34:34,669 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:34:34,676 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:34:34,677 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:34:43,401 [SYNTHESIZER] - Generating pipeline for segment (987242.061, 1017158.487]
# INFO: 2023-09-18 14:34:43,406 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:34:43,413 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:34:43,414 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:34:52,295 [SYNTHESIZER] - Generating pipeline for segment (1017158.487, 1047074.913]
# INFO: 2023-09-18 14:34:52,299 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:34:52,306 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:34:52,307 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:35:01,091 [SYNTHESIZER] - Generating pipeline for segment (1047074.913, 1076991.339]
# INFO: 2023-09-18 14:35:01,096 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:35:01,103 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:35:01,104 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:35:09,916 [SYNTHESIZER] - Generating pipeline for segment (1076991.339, 1106907.765]
# INFO: 2023-09-18 14:35:09,921 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:35:09,927 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:35:09,928 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:35:18,695 [SYNTHESIZER] - Generating pipeline for segment (1106907.765, 1136824.191]
# INFO: 2023-09-18 14:35:18,700 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:35:18,707 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:35:18,708 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:35:27,407 [SYNTHESIZER] - Generating pipeline for segment (1136824.191, 1166740.617]
# INFO: 2023-09-18 14:35:27,412 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:35:27,419 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:35:27,420 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:35:35,794 [SYNTHESIZER] - Generating pipeline for segment (1166740.617, 1196657.043]
# INFO: 2023-09-18 14:35:35,799 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:35:35,806 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:35:35,807 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:35:44,396 [SYNTHESIZER] - Generating pipeline for segment (1196657.043, 1226573.47]
# INFO: 2023-09-18 14:35:44,401 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:35:44,408 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:35:44,409 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:35:52,995 [SYNTHESIZER] - Generating pipeline for segment (1226573.47, 1256489.896]
# INFO: 2023-09-18 14:35:53,001 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:35:53,009 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:35:53,009 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:36:01,847 [SYNTHESIZER] - Generating pipeline for segment (1256489.896, 1286406.322]
# INFO: 2023-09-18 14:36:01,852 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:36:01,859 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:36:01,860 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:36:10,555 [SYNTHESIZER] - Generating pipeline for segment (1286406.322, 1316322.748]
# INFO: 2023-09-18 14:36:10,560 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:36:10,567 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:36:10,568 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:36:19,500 [SYNTHESIZER] - Generating pipeline for segment (1316322.748, 1346239.174]
# INFO: 2023-09-18 14:36:19,505 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:36:19,512 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:36:19,513 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:36:28,300 [SYNTHESIZER] - Generating pipeline for segment (1346239.174, 1376155.6]
# INFO: 2023-09-18 14:36:28,305 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:36:28,312 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:36:28,313 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:36:37,123 [SYNTHESIZER] - Generating pipeline for segment (1376155.6, 1406072.026]
# INFO: 2023-09-18 14:36:37,128 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:36:37,135 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:36:37,136 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:36:45,867 [SYNTHESIZER] - Generating pipeline for segment (1406072.026, 1435988.452]
# INFO: 2023-09-18 14:36:45,872 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:36:45,878 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:36:45,879 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:36:54,483 [SYNTHESIZER] - Generating pipeline for segment (1435988.452, 1465904.878]
# INFO: 2023-09-18 14:36:54,488 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:36:54,495 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:36:54,496 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:37:03,132 [SYNTHESIZER] - Generating pipeline for segment (1465904.878, 1495821.304]
# INFO: 2023-09-18 14:37:03,137 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:37:03,144 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:37:03,145 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:37:11,684 [SYNTHESIZER] - Generating pipeline for segment (1495821.304, 1525737.73]
# INFO: 2023-09-18 14:37:11,689 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:37:11,696 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:37:11,697 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:37:20,307 [SYNTHESIZER] - Generating pipeline for segment (1525737.73, 1555654.157]
# INFO: 2023-09-18 14:37:20,312 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:37:20,318 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:37:20,319 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:37:29,066 [SYNTHESIZER] - Generating pipeline for segment (1555654.157, 1585570.583]
# INFO: 2023-09-18 14:37:29,071 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:37:29,078 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:37:29,079 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:37:37,933 [SYNTHESIZER] - Generating pipeline for segment (1585570.583, 1615487.009]
# INFO: 2023-09-18 14:37:37,938 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:37:37,945 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:37:37,946 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:37:46,846 [SYNTHESIZER] - Generating pipeline for segment (1615487.009, 1645403.435]
# INFO: 2023-09-18 14:37:46,851 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:37:46,858 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:37:46,859 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:37:55,484 [SYNTHESIZER] - Generating pipeline for segment (1645403.435, 1675319.861]
# INFO: 2023-09-18 14:37:55,489 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:37:55,496 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:37:55,497 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:38:04,533 [SYNTHESIZER] - Generating pipeline for segment (1675319.861, 1705236.287]
# INFO: 2023-09-18 14:38:04,538 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:38:04,545 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:38:04,545 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:38:13,024 [SYNTHESIZER] - Generating pipeline for segment (1705236.287, 1735152.713]
# INFO: 2023-09-18 14:38:13,029 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:38:13,036 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:38:13,037 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:38:21,326 [SYNTHESIZER] - Generating pipeline for segment (1735152.713, 1765069.139]
# INFO: 2023-09-18 14:38:21,331 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:38:21,338 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:38:21,338 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:38:29,869 [SYNTHESIZER] - Generating pipeline for segment (1765069.139, 1794985.565]
# INFO: 2023-09-18 14:38:29,874 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:38:29,881 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:38:29,882 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:38:38,463 [SYNTHESIZER] - Generating pipeline for segment (1794985.565, 1824901.991]
# INFO: 2023-09-18 14:38:38,468 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:38:38,475 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:38:38,476 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:38:47,277 [SYNTHESIZER] - Generating pipeline for segment (1824901.991, 1854818.417]
# INFO: 2023-09-18 14:38:47,282 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:38:47,289 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:38:47,289 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:38:55,935 [SYNTHESIZER] - Generating pipeline for segment (1854818.417, 1884734.843]
# INFO: 2023-09-18 14:38:55,940 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:38:55,947 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:38:55,947 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:39:04,823 [SYNTHESIZER] - Generating pipeline for segment (1884734.843, 1914651.27]
# INFO: 2023-09-18 14:39:04,828 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:39:04,835 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:39:04,836 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:39:13,872 [SYNTHESIZER] - Generating pipeline for segment (1914651.27, 1944567.696]
# INFO: 2023-09-18 14:39:13,877 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:39:13,884 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:39:13,885 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:39:22,924 [SYNTHESIZER] - Generating pipeline for segment (1944567.696, 1974484.122]
# INFO: 2023-09-18 14:39:22,929 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:39:22,936 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:39:22,937 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:39:31,439 [SYNTHESIZER] - Generating pipeline for segment (1974484.122, 2004400.548]
# INFO: 2023-09-18 14:39:31,444 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:39:31,451 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:39:31,452 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:39:40,123 [SYNTHESIZER] - Generating pipeline for segment (2004400.548, 2034316.974]
# INFO: 2023-09-18 14:39:40,128 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:39:40,135 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:39:40,136 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:39:48,671 [SYNTHESIZER] - Generating pipeline for segment (2034316.974, 2064233.4]
# INFO: 2023-09-18 14:39:48,675 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:39:48,682 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:39:48,683 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:39:57,112 [SYNTHESIZER] - Generating pipeline for segment (2064233.4, 2094149.826]
# INFO: 2023-09-18 14:39:57,117 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:39:57,125 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:39:57,126 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:40:05,932 [SYNTHESIZER] - Generating pipeline for segment (2094149.826, 2124066.252]
# INFO: 2023-09-18 14:40:05,937 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:40:05,944 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:40:05,945 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:40:14,713 [SYNTHESIZER] - Generating pipeline for segment (2124066.252, 2153982.678]
# INFO: 2023-09-18 14:40:14,718 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:40:14,725 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:40:14,726 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:40:23,732 [SYNTHESIZER] - Generating pipeline for segment (2153982.678, 2183899.104]
# INFO: 2023-09-18 14:40:23,737 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:40:23,744 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:40:23,745 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:40:32,455 [SYNTHESIZER] - Generating pipeline for segment (2183899.104, 2213815.53]
# INFO: 2023-09-18 14:40:32,460 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:40:32,467 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:40:32,468 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:40:40,917 [SYNTHESIZER] - Generating pipeline for segment (2213815.53, 2243731.957]
# INFO: 2023-09-18 14:40:40,922 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:40:40,929 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:40:40,929 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:40:49,345 [SYNTHESIZER] - Generating pipeline for segment (2243731.957, 2273648.383]
# INFO: 2023-09-18 14:40:49,350 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:40:49,356 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:40:49,358 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:40:57,978 [SYNTHESIZER] - Generating pipeline for segment (2273648.383, 2303564.809]
# INFO: 2023-09-18 14:40:57,983 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:40:57,990 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:40:57,991 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:41:06,781 [SYNTHESIZER] - Generating pipeline for segment (2303564.809, 2333481.235]
# INFO: 2023-09-18 14:41:06,786 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:41:06,793 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:41:06,794 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:41:15,605 [SYNTHESIZER] - Generating pipeline for segment (2333481.235, 2363397.661]
# INFO: 2023-09-18 14:41:15,610 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:41:15,617 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:41:15,618 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:41:24,362 [SYNTHESIZER] - Generating pipeline for segment (2363397.661, 2393314.087]
# INFO: 2023-09-18 14:41:24,367 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:41:24,374 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:41:24,375 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:41:33,044 [SYNTHESIZER] - Generating pipeline for segment (2393314.087, 2423230.513]
# INFO: 2023-09-18 14:41:33,048 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:41:33,055 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:41:33,056 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:41:42,023 [SYNTHESIZER] - Generating pipeline for segment (2423230.513, 2453146.939]
# INFO: 2023-09-18 14:41:42,028 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:41:42,035 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:41:42,036 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:41:50,490 [SYNTHESIZER] - Generating pipeline for segment (2453146.939, 2483063.365]
# INFO: 2023-09-18 14:41:50,495 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:41:50,502 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:41:50,502 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:41:58,920 [SYNTHESIZER] - Generating pipeline for segment (2483063.365, 2512979.791]
# INFO: 2023-09-18 14:41:58,925 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:41:58,932 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:41:58,933 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:42:07,614 [SYNTHESIZER] - Generating pipeline for segment (2512979.791, 2542896.217]
# INFO: 2023-09-18 14:42:07,620 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:42:07,628 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:42:07,628 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:42:16,433 [SYNTHESIZER] - Generating pipeline for segment (2542896.217, 2572812.643]
# INFO: 2023-09-18 14:42:16,438 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:42:16,444 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:42:16,445 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:42:25,367 [SYNTHESIZER] - Generating pipeline for segment (2572812.643, 2602729.07]
# INFO: 2023-09-18 14:42:25,372 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:42:25,379 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:42:25,380 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:42:34,198 [SYNTHESIZER] - Generating pipeline for segment (2602729.07, 2632645.496]
# INFO: 2023-09-18 14:42:34,203 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:42:34,209 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:42:34,210 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:42:43,077 [SYNTHESIZER] - Generating pipeline for segment (2632645.496, 2662561.922]
# INFO: 2023-09-18 14:42:43,082 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:42:43,089 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:42:43,090 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:42:51,806 [SYNTHESIZER] - Generating pipeline for segment (2662561.922, 2692478.348]
# INFO: 2023-09-18 14:42:51,811 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:42:51,818 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:42:51,819 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:43:00,524 [SYNTHESIZER] - Generating pipeline for segment (2692478.348, 2722394.774]
# INFO: 2023-09-18 14:43:00,529 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:43:00,536 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:43:00,537 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:43:09,324 [SYNTHESIZER] - Generating pipeline for segment (2722394.774, 2752311.2]
# INFO: 2023-09-18 14:43:09,329 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:43:09,336 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:43:09,337 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:43:18,216 [SYNTHESIZER] - Generating pipeline for segment (2752311.2, 2782227.626]
# INFO: 2023-09-18 14:43:18,220 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:43:18,227 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:43:18,228 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:43:27,066 [SYNTHESIZER] - Generating pipeline for segment (2782227.626, 2812144.052]
# INFO: 2023-09-18 14:43:27,071 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:43:27,077 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:43:27,078 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:43:35,793 [SYNTHESIZER] - Generating pipeline for segment (2812144.052, 2842060.478]
# INFO: 2023-09-18 14:43:35,798 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:43:35,805 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:43:35,806 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:43:44,223 [SYNTHESIZER] - Generating pipeline for segment (2842060.478, 2871976.904]
# INFO: 2023-09-18 14:43:44,228 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:43:44,235 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:43:44,236 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:43:53,121 [SYNTHESIZER] - Generating pipeline for segment (2871976.904, 2901893.33]
# INFO: 2023-09-18 14:43:53,126 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:43:53,133 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:43:53,134 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:44:01,768 [SYNTHESIZER] - Generating pipeline for segment (2901893.33, 2931809.757]
# INFO: 2023-09-18 14:44:01,773 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:44:01,779 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:44:01,780 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:44:10,443 [SYNTHESIZER] - Generating pipeline for segment (2931809.757, 2961726.183]
# INFO: 2023-09-18 14:44:10,449 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:44:10,456 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:44:10,457 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:44:19,241 [SYNTHESIZER] - Generating pipeline for segment (2961726.183, 2991642.609]
# INFO: 2023-09-18 14:44:19,246 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:44:19,253 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:44:19,254 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:44:28,170 [SYNTHESIZER] - Generating pipeline for segment (2991642.609, 3021559.035]
# INFO: 2023-09-18 14:44:28,176 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:44:28,182 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:44:28,183 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:44:37,003 [SYNTHESIZER] - Generating pipeline for segment (3021559.035, 3051475.461]
# INFO: 2023-09-18 14:44:37,008 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:44:37,015 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:44:37,016 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:44:45,605 [SYNTHESIZER] - Generating pipeline for segment (3051475.461, 3081391.887]
# INFO: 2023-09-18 14:44:45,610 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:44:45,617 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:44:45,618 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:44:54,212 [SYNTHESIZER] - Generating pipeline for segment (3081391.887, 3111308.313]
# INFO: 2023-09-18 14:44:54,217 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:44:54,225 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:44:54,226 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:45:02,837 [SYNTHESIZER] - Generating pipeline for segment (3111308.313, 3141224.739]
# INFO: 2023-09-18 14:45:02,842 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:45:02,849 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:45:02,850 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:45:11,549 [SYNTHESIZER] - Generating pipeline for segment (3141224.739, 3171141.165]
# INFO: 2023-09-18 14:45:11,554 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:45:11,561 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:45:11,561 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:45:20,787 [SYNTHESIZER] - Generating pipeline for segment (3171141.165, 3201057.591]
# INFO: 2023-09-18 14:45:20,792 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:45:20,798 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:45:20,799 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:45:29,587 [SYNTHESIZER] - Generating pipeline for segment (3201057.591, 3230974.017]
# INFO: 2023-09-18 14:45:29,592 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:45:29,599 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:45:29,600 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:45:38,541 [SYNTHESIZER] - Generating pipeline for segment (3230974.017, 3260890.443]
# INFO: 2023-09-18 14:45:38,546 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:45:38,553 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:45:38,554 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:45:46,759 [SYNTHESIZER] - Generating pipeline for segment (3260890.443, 3290806.87]
# INFO: 2023-09-18 14:45:46,764 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:45:46,772 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:45:46,773 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:45:55,412 [SYNTHESIZER] - Generating pipeline for segment (3290806.87, 3320723.296]
# INFO: 2023-09-18 14:45:55,417 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:45:55,424 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:45:55,424 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:46:04,312 [SYNTHESIZER] - Generating pipeline for segment (3320723.296, 3350639.722]
# INFO: 2023-09-18 14:46:04,317 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:46:04,324 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:46:04,324 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:46:13,161 [SYNTHESIZER] - Generating pipeline for segment (3350639.722, 3380556.148]
# INFO: 2023-09-18 14:46:13,166 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:46:13,174 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:46:13,175 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:46:22,064 [SYNTHESIZER] - Generating pipeline for segment (3380556.148, 3410472.574]
# INFO: 2023-09-18 14:46:22,069 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:46:22,076 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:46:22,077 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.
# INFO: 2023-09-18 14:46:30,911 [SYNTHESIZER] - Generating pipeline for segment (3410472.574, 3440389.0]
# INFO: 2023-09-18 14:46:30,916 [SYNTHESIZER] - Preprocess segment
# INFO: 2023-09-18 14:46:30,922 [SYNTHESIZER] - Synthesizer init.
# INFO: 2023-09-18 14:46:30,923 [SYNTHESIZER] - Processing the data prior fitting the synthesizer.

# %% [markdown]
# As we want to replicate this dataset, let's generate a sample as large as the original dataset.

# %%
# Generating a sam synthetic data
synth = synthesizer.sample()
# Out:
# INFO: 2023-09-18 14:46:39,753 [SYNTHESIZER] - Start generating model samples.
# INFO: 2023-09-18 14:46:39,755 [SYNTHESIZER] - Sample segment (-0.001, 29916.426]
# INFO: 2023-09-18 14:46:43,088 [SYNTHESIZER] - Sample segment (29916.426, 59832.852]
# INFO: 2023-09-18 14:46:46,312 [SYNTHESIZER] - Sample segment (59832.852, 89749.278]
# INFO: 2023-09-18 14:46:49,280 [SYNTHESIZER] - Sample segment (89749.278, 119665.704]
# INFO: 2023-09-18 14:46:52,386 [SYNTHESIZER] - Sample segment (119665.704, 149582.13]
# INFO: 2023-09-18 14:46:55,652 [SYNTHESIZER] - Sample segment (149582.13, 179498.557]
# INFO: 2023-09-18 14:46:58,782 [SYNTHESIZER] - Sample segment (179498.557, 209414.983]
# INFO: 2023-09-18 14:47:01,906 [SYNTHESIZER] - Sample segment (209414.983, 239331.409]
# INFO: 2023-09-18 14:47:05,124 [SYNTHESIZER] - Sample segment (239331.409, 269247.835]
# INFO: 2023-09-18 14:47:08,168 [SYNTHESIZER] - Sample segment (269247.835, 299164.261]
# INFO: 2023-09-18 14:47:11,249 [SYNTHESIZER] - Sample segment (299164.261, 329080.687]
# INFO: 2023-09-18 14:47:14,535 [SYNTHESIZER] - Sample segment (329080.687, 358997.113]
# INFO: 2023-09-18 14:47:17,640 [SYNTHESIZER] - Sample segment (358997.113, 388913.539]
# INFO: 2023-09-18 14:47:20,881 [SYNTHESIZER] - Sample segment (388913.539, 418829.965]
# INFO: 2023-09-18 14:47:23,792 [SYNTHESIZER] - Sample segment (418829.965, 448746.391]
# INFO: 2023-09-18 14:47:27,012 [SYNTHESIZER] - Sample segment (448746.391, 478662.817]
# INFO: 2023-09-18 14:47:30,015 [SYNTHESIZER] - Sample segment (478662.817, 508579.243]
# INFO: 2023-09-18 14:47:33,178 [SYNTHESIZER] - Sample segment (508579.243, 538495.67]
# INFO: 2023-09-18 14:47:36,296 [SYNTHESIZER] - Sample segment (538495.67, 568412.096]
# INFO: 2023-09-18 14:47:39,610 [SYNTHESIZER] - Sample segment (568412.096, 598328.522]
# INFO: 2023-09-18 14:47:42,837 [SYNTHESIZER] - Sample segment (598328.522, 628244.948]
# INFO: 2023-09-18 14:47:45,954 [SYNTHESIZER] - Sample segment (628244.948, 658161.374]
# INFO: 2023-09-18 14:47:49,217 [SYNTHESIZER] - Sample segment (658161.374, 688077.8]
# INFO: 2023-09-18 14:47:52,339 [SYNTHESIZER] - Sample segment (688077.8, 717994.226]
# INFO: 2023-09-18 14:47:55,718 [SYNTHESIZER] - Sample segment (717994.226, 747910.652]
# INFO: 2023-09-18 14:47:58,928 [SYNTHESIZER] - Sample segment (747910.652, 777827.078]
# INFO: 2023-09-18 14:48:02,024 [SYNTHESIZER] - Sample segment (777827.078, 807743.504]
# INFO: 2023-09-18 14:48:05,141 [SYNTHESIZER] - Sample segment (807743.504, 837659.93]
# INFO: 2023-09-18 14:48:08,297 [SYNTHESIZER] - Sample segment (837659.93, 867576.357]
# INFO: 2023-09-18 14:48:11,567 [SYNTHESIZER] - Sample segment (867576.357, 897492.783]
# INFO: 2023-09-18 14:48:14,655 [SYNTHESIZER] - Sample segment (897492.783, 927409.209]
# INFO: 2023-09-18 14:48:17,995 [SYNTHESIZER] - Sample segment (927409.209, 957325.635]
# INFO: 2023-09-18 14:48:21,320 [SYNTHESIZER] - Sample segment (957325.635, 987242.061]
# INFO: 2023-09-18 14:48:24,584 [SYNTHESIZER] - Sample segment (987242.061, 1017158.487]
# INFO: 2023-09-18 14:48:27,789 [SYNTHESIZER] - Sample segment (1017158.487, 1047074.913]
# INFO: 2023-09-18 14:48:31,053 [SYNTHESIZER] - Sample segment (1047074.913, 1076991.339]
# INFO: 2023-09-18 14:48:34,202 [SYNTHESIZER] - Sample segment (1076991.339, 1106907.765]
# INFO: 2023-09-18 14:48:37,426 [SYNTHESIZER] - Sample segment (1106907.765, 1136824.191]
# INFO: 2023-09-18 14:48:40,602 [SYNTHESIZER] - Sample segment (1136824.191, 1166740.617]
# INFO: 2023-09-18 14:48:43,805 [SYNTHESIZER] - Sample segment (1166740.617, 1196657.043]
# INFO: 2023-09-18 14:48:46,918 [SYNTHESIZER] - Sample segment (1196657.043, 1226573.47]
# INFO: 2023-09-18 14:48:50,020 [SYNTHESIZER] - Sample segment (1226573.47, 1256489.896]
# INFO: 2023-09-18 14:48:53,336 [SYNTHESIZER] - Sample segment (1256489.896, 1286406.322]
# INFO: 2023-09-18 14:48:56,584 [SYNTHESIZER] - Sample segment (1286406.322, 1316322.748]
# INFO: 2023-09-18 14:48:59,757 [SYNTHESIZER] - Sample segment (1316322.748, 1346239.174]
# INFO: 2023-09-18 14:49:02,871 [SYNTHESIZER] - Sample segment (1346239.174, 1376155.6]
# INFO: 2023-09-18 14:49:06,011 [SYNTHESIZER] - Sample segment (1376155.6, 1406072.026]
# INFO: 2023-09-18 14:49:09,124 [SYNTHESIZER] - Sample segment (1406072.026, 1435988.452]
# INFO: 2023-09-18 14:49:12,449 [SYNTHESIZER] - Sample segment (1435988.452, 1465904.878]
# INFO: 2023-09-18 14:49:15,530 [SYNTHESIZER] - Sample segment (1465904.878, 1495821.304]
# INFO: 2023-09-18 14:49:18,622 [SYNTHESIZER] - Sample segment (1495821.304, 1525737.73]
# INFO: 2023-09-18 14:49:21,694 [SYNTHESIZER] - Sample segment (1525737.73, 1555654.157]
# INFO: 2023-09-18 14:49:24,956 [SYNTHESIZER] - Sample segment (1555654.157, 1585570.583]
# INFO: 2023-09-18 14:49:28,271 [SYNTHESIZER] - Sample segment (1585570.583, 1615487.009]
# INFO: 2023-09-18 14:49:31,559 [SYNTHESIZER] - Sample segment (1615487.009, 1645403.435]
# INFO: 2023-09-18 14:49:34,767 [SYNTHESIZER] - Sample segment (1645403.435, 1675319.861]
# INFO: 2023-09-18 14:49:37,927 [SYNTHESIZER] - Sample segment (1675319.861, 1705236.287]
# INFO: 2023-09-18 14:49:41,097 [SYNTHESIZER] - Sample segment (1705236.287, 1735152.713]
# INFO: 2023-09-18 14:49:44,057 [SYNTHESIZER] - Sample segment (1735152.713, 1765069.139]
# INFO: 2023-09-18 14:49:47,360 [SYNTHESIZER] - Sample segment (1765069.139, 1794985.565]
# INFO: 2023-09-18 14:49:50,646 [SYNTHESIZER] - Sample segment (1794985.565, 1824901.991]
# INFO: 2023-09-18 14:49:53,965 [SYNTHESIZER] - Sample segment (1824901.991, 1854818.417]
# INFO: 2023-09-18 14:49:57,202 [SYNTHESIZER] - Sample segment (1854818.417, 1884734.843]
# INFO: 2023-09-18 14:50:00,617 [SYNTHESIZER] - Sample segment (1884734.843, 1914651.27]
# INFO: 2023-09-18 14:50:03,923 [SYNTHESIZER] - Sample segment (1914651.27, 1944567.696]
# INFO: 2023-09-18 14:50:07,185 [SYNTHESIZER] - Sample segment (1944567.696, 1974484.122]
# INFO: 2023-09-18 14:50:10,216 [SYNTHESIZER] - Sample segment (1974484.122, 2004400.548]
# INFO: 2023-09-18 14:50:13,437 [SYNTHESIZER] - Sample segment (2004400.548, 2034316.974]
# INFO: 2023-09-18 14:50:16,543 [SYNTHESIZER] - Sample segment (2034316.974, 2064233.4]
# INFO: 2023-09-18 14:50:19,644 [SYNTHESIZER] - Sample segment (2064233.4, 2094149.826]
# INFO: 2023-09-18 14:50:22,851 [SYNTHESIZER] - Sample segment (2094149.826, 2124066.252]
# INFO: 2023-09-18 14:50:26,127 [SYNTHESIZER] - Sample segment (2124066.252, 2153982.678]
# INFO: 2023-09-18 14:50:29,336 [SYNTHESIZER] - Sample segment (2153982.678, 2183899.104]
# INFO: 2023-09-18 14:50:32,635 [SYNTHESIZER] - Sample segment (2183899.104, 2213815.53]
# INFO: 2023-09-18 14:50:35,672 [SYNTHESIZER] - Sample segment (2213815.53, 2243731.957]
# INFO: 2023-09-18 14:50:38,895 [SYNTHESIZER] - Sample segment (2243731.957, 2273648.383]
# INFO: 2023-09-18 14:50:42,028 [SYNTHESIZER] - Sample segment (2273648.383, 2303564.809]
# INFO: 2023-09-18 14:50:45,172 [SYNTHESIZER] - Sample segment (2303564.809, 2333481.235]
# INFO: 2023-09-18 14:50:48,329 [SYNTHESIZER] - Sample segment (2333481.235, 2363397.661]
# INFO: 2023-09-18 14:50:51,407 [SYNTHESIZER] - Sample segment (2363397.661, 2393314.087]
# INFO: 2023-09-18 14:50:54,581 [SYNTHESIZER] - Sample segment (2393314.087, 2423230.513]
# INFO: 2023-09-18 14:50:57,860 [SYNTHESIZER] - Sample segment (2423230.513, 2453146.939]
# INFO: 2023-09-18 14:51:00,892 [SYNTHESIZER] - Sample segment (2453146.939, 2483063.365]
# INFO: 2023-09-18 14:51:03,896 [SYNTHESIZER] - Sample segment (2483063.365, 2512979.791]
# INFO: 2023-09-18 14:51:07,099 [SYNTHESIZER] - Sample segment (2512979.791, 2542896.217]
# INFO: 2023-09-18 14:51:10,351 [SYNTHESIZER] - Sample segment (2542896.217, 2572812.643]
# INFO: 2023-09-18 14:51:13,533 [SYNTHESIZER] - Sample segment (2572812.643, 2602729.07]
# INFO: 2023-09-18 14:51:16,701 [SYNTHESIZER] - Sample segment (2602729.07, 2632645.496]
# INFO: 2023-09-18 14:51:19,877 [SYNTHESIZER] - Sample segment (2632645.496, 2662561.922]
# INFO: 2023-09-18 14:51:23,085 [SYNTHESIZER] - Sample segment (2662561.922, 2692478.348]
# INFO: 2023-09-18 14:51:26,252 [SYNTHESIZER] - Sample segment (2692478.348, 2722394.774]
# INFO: 2023-09-18 14:51:29,352 [SYNTHESIZER] - Sample segment (2722394.774, 2752311.2]
# INFO: 2023-09-18 14:51:32,473 [SYNTHESIZER] - Sample segment (2752311.2, 2782227.626]
# INFO: 2023-09-18 14:51:35,719 [SYNTHESIZER] - Sample segment (2782227.626, 2812144.052]
# INFO: 2023-09-18 14:51:38,848 [SYNTHESIZER] - Sample segment (2812144.052, 2842060.478]
# INFO: 2023-09-18 14:51:41,851 [SYNTHESIZER] - Sample segment (2842060.478, 2871976.904]
# INFO: 2023-09-18 14:51:45,094 [SYNTHESIZER] - Sample segment (2871976.904, 2901893.33]
# INFO: 2023-09-18 14:51:48,162 [SYNTHESIZER] - Sample segment (2901893.33, 2931809.757]
# INFO: 2023-09-18 14:51:51,239 [SYNTHESIZER] - Sample segment (2931809.757, 2961726.183]
# INFO: 2023-09-18 14:51:54,668 [SYNTHESIZER] - Sample segment (2961726.183, 2991642.609]
# INFO: 2023-09-18 14:51:57,827 [SYNTHESIZER] - Sample segment (2991642.609, 3021559.035]
# INFO: 2023-09-18 14:52:01,035 [SYNTHESIZER] - Sample segment (3021559.035, 3051475.461]
# INFO: 2023-09-18 14:52:04,272 [SYNTHESIZER] - Sample segment (3051475.461, 3081391.887]
# INFO: 2023-09-18 14:52:07,583 [SYNTHESIZER] - Sample segment (3081391.887, 3111308.313]
# INFO: 2023-09-18 14:52:10,792 [SYNTHESIZER] - Sample segment (3111308.313, 3141224.739]
# INFO: 2023-09-18 14:52:14,001 [SYNTHESIZER] - Sample segment (3141224.739, 3171141.165]
# INFO: 2023-09-18 14:52:17,210 [SYNTHESIZER] - Sample segment (3171141.165, 3201057.591]
# INFO: 2023-09-18 14:52:20,580 [SYNTHESIZER] - Sample segment (3201057.591, 3230974.017]
# INFO: 2023-09-18 14:52:23,773 [SYNTHESIZER] - Sample segment (3230974.017, 3260890.443]
# INFO: 2023-09-18 14:52:26,737 [SYNTHESIZER] - Sample segment (3260890.443, 3290806.87]
# INFO: 2023-09-18 14:52:29,818 [SYNTHESIZER] - Sample segment (3290806.87, 3320723.296]
# INFO: 2023-09-18 14:52:33,062 [SYNTHESIZER] - Sample segment (3320723.296, 3350639.722]
# INFO: 2023-09-18 14:52:36,164 [SYNTHESIZER] - Sample segment (3350639.722, 3380556.148]
# INFO: 2023-09-18 14:52:39,236 [SYNTHESIZER] - Sample segment (3380556.148, 3410472.574]
# INFO: 2023-09-18 14:52:42,420 [SYNTHESIZER] - Sample segment (3410472.574, 3440389.0]

# %%
# The synthesized dataset
synth.head(10)
# Out:
#    time   action     amount     nameOrig     nameDest  isFraud
# 0     1  CASH_IN  229382.36  C3568019779  M1836583048        0
# 1     1  CASH_IN   97393.77  C2836521631  M4632515968        0
# 2     2  CASH_IN  155631.49  C9511918875  M3682642089        0
# 3     3  CASH_IN  229382.36  C4735208556  M7113244499        0
# 4     4  CASH_IN  131959.06  C9591120449  M6409786995        0
# 5     5  CASH_IN  107467.37  C0981136732  M3327903275        0
# 6     5  CASH_IN  230127.38  C1107137053  M2736406736        0
# 7     8  CASH_IN  326455.82  C7730736547  M9290819283        0
# 8     8  CASH_IN  122791.96  C8050477779  M4934014946        0
# 9     8  CASH_IN  295165.00  C5638823223  M5586772524        0

# %%
# Saving to .csv
from ydata.connectors import LocalConnector
from ydata.connectors.filetype import FileType

conn = LocalConnector()
conn.write_file(synth, 'data/new_synth_sample.csv', file_type=FileType.CSV)

# %% [markdown]
# ### Calculating the constrained features - balances

# %% [markdown]
# To get a full replica, we need to re-add the balances and overdraft flags following the business logic described above. It's a matter of keeping a global per-entity state of the balance and, for every transaction:
# - verifying whether it's an overdraft
# - update the old and new balances of the origin and destination entities according to the transaction type
#
# The function `calculate_balance_with_interactions` does just that. It contains a fundamental assumption: the starting balance of all entities is zero. For specific use cases, this assumption could be tweaked - as it will probably not hold true in most real life scenarios.
#
# The business logic expressed in this function could also be changed to, for instance, test new hypothesis while guaranteeing the distribution of transaction amounts and types is kept.

# %%
#from utils import calculate_balance_with_interactions
import pandas as pd
# %run utils.py

pd_synth = synth.to_pandas()
balances = calculate_balance_with_interactions(pd_synth)

# %% [markdown]
# Let's join the two dataframes and have a **new dataset combining smart synthetic data with precise business logic for balance calculation**:

# %%
full_synth = pd.concat([pd_synth, balances], axis=1)
full_synth.head()
# Out:
#    time   action     amount     nameOrig     nameDest  isFraud  \
# 0     1  CASH_IN  229382.36  C3568019779  M1836583048        0
# 1     1  CASH_IN   97393.77  C2836521631  M4632515968        0
# 2     2  CASH_IN  155631.49  C9511918875  M3682642089        0
# 3     3  CASH_IN  229382.36  C4735208556  M7113244499        0
# 4     4  CASH_IN  131959.06  C9591120449  M6409786995        0
#
#    oldBalanceOrig  newBalanceOrig  oldBalanceDest  newBalanceDest  \
# 0             0.0       229382.36             0.0             0.0
# 1             0.0        97393.77             0.0             0.0
# 2             0.0       155631.49             0.0             0.0
# 3             0.0       229382.36             0.0             0.0
# 4             0.0       131959.06             0.0             0.0
#
#    isUnauthorizedOverdraft
# 0                        0
# 1                        0
# 2                        0
# 3                        0
# 4                        0

# %%
from ydata.connectors import LocalConnector
from ydata.connectors.filetype import FileType

conn = LocalConnector()
conn.write_file(full_synth, 'data/new_synth_sample_with_balances.csv', file_type=FileType.CSV)

# %% [markdown]
# ## Evaluating the quality of the synthetic dataset

# %%
#import pandas as pd
#full_synth = pd.read_csv("data/new_synth_sample_with_balances.csv")

# %% [markdown]
# For the dataset to be useful in use cases such as data sharing (for testing), it needs to show the same statistical fidelity, coherence and abidance by business logic. Let's verify that.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(font_scale=1.5)
sns.set_theme(style="whitegrid", rc={"axes.labelcolor": '#7A7A7A', "font.size": 12, "figure.titlesize": 16, "axes.labelsize": 12})
REAL_COLOR = '#474747'
SYNTH_COLOR = '#E32212'
# Out:
# INFO: 2023-09-18 15:22:33,567 generated new fontManager

# %% [markdown]
# **Shape and data types**

# %%
original = dataset.to_pandas()
full_synth = full_synth[original.columns.tolist()] # re-ordering columns

# %%
print(original.dtypes, '\n\n', full_synth.dtypes)
# Out:
# time                         int64
# action                      string
# amount                     float64
# nameOrig                    string
# oldBalanceOrig             float64
# newBalanceOrig             float64
# nameDest                    string
# oldBalanceDest             float64
# newBalanceDest             float64
# isFraud                      int64
# isUnauthorizedOverdraft      int64
# dtype: object
#
#  time                         int64
# action                      string
# amount                     float64
# nameOrig                    string
# oldBalanceOrig             float64
# newBalanceOrig             float64
# nameDest                    string
# oldBalanceDest             float64
# newBalanceDest             float64
# isFraud                      int64
# isUnauthorizedOverdraft      int64
# dtype: object

# %%
print(original.shape, full_synth.shape)
# Out:
# (3440390, 11) (3440390, 11)

# %% [markdown]
# As expected, the shapes and data types of both datasets match.

# %% [markdown]
# **Types of transactions**

# %%
original_ops = original.action.value_counts()
synth_ops = full_synth.action.value_counts()

ops_data = {
    'Data': len(original_ops) * ['Original'] + len(original_ops) * ['Synthetic'],
    'Transaction': original_ops.index.tolist() + synth_ops.index.tolist(),
    'Count': list(original_ops.values) + list(synth_ops.values)
}
ops_df = pd.DataFrame(ops_data)

# %%
fig, ax = plt.subplots(figsize=[11, 8])
b=sns.barplot(data=ops_df,
            y='Transaction',
            x='Count',
            hue='Data',
            orient='h',
            ax=ax,
            palette=[REAL_COLOR, SYNTH_COLOR],
            alpha=1.0,
            )
b.set_xscale("log")
fig.suptitle("Transactions per type in real and synthetic datasets")
ax.set_xlabel("Number of transactions (logarithmic scale)")
ax.set_ylabel("Type")
plt.legend(loc='lower right')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Number of unique origin entities (customers)**

# %% [markdown]
# As the only origin entity we have is _Customers_, we can just compare the number of unique origin entities between the two datasets.

# %%
len(original.nameOrig.unique())
# Out:
# 20755

# %%
len(full_synth.nameOrig.unique())
# Out:
# 20550

# %% [markdown]
# **Number of unique destination entities (customers, merchants, banks)**

# %% [markdown]
# For destination entities (which can be _Customers_, _Merchants_ or _Banks_), we need to visualize:

# %%
original_banks = len(original[original.nameDest.str[0] == 'B'].nameDest.unique())
original_customers = len(original[original.nameDest.str[0] == 'C'].nameDest.unique())
original_merchants = len(original[original.nameDest.str[0] == 'M'].nameDest.unique())
synth_banks = len(full_synth[full_synth.nameDest.str[0] == 'B'].nameDest.unique())
synth_customers = len(full_synth[full_synth.nameDest.str[0] == 'C'].nameDest.unique())
synth_merchants = len(full_synth[full_synth.nameDest.str[0] == 'M'].nameDest.unique())

dest_data = {
    'Data': 3 * ['Original'] + 3 * ['Synthetic'] ,
    'Entity': ['Banks', 'Customers', 'Merchants'] * 2,
    'Count': [original_banks, original_customers, original_merchants, synth_banks, synth_customers, synth_merchants]
}

dest_df = pd.DataFrame(dest_data)

# %%
fig, ax = plt.subplots(figsize=[11, 8])
b=sns.barplot(data=dest_df,
            y='Entity',
            x='Count',
            hue='Data',
            orient='h',
            ax=ax,
            palette=[REAL_COLOR, SYNTH_COLOR],
            alpha=1.0,
            )
b.set_xscale("log")
fig.suptitle("Unique destination entities in real and synthetic datasets")
ax.set_ylabel("Entity type")
ax.set_xlabel("Number of entities (logarithmic scale)")
plt.tight_layout()
plt.show()

# %% [markdown]
# **Fraudulent events**

# %%
original_fraud = original[original.isFraud == 1].action.value_counts()
synth_fraud = original[original.isFraud==1].action.value_counts()

fraud_data = {
    'Data': len(original_fraud) * ['Original'] + len(synth_fraud) * ['Synthetic'],
    'Type': original_fraud.index.tolist() + synth_fraud.index.tolist(),
    'Count': list(original_fraud.values) + list(synth_fraud.values)
}
fraud_df = pd.DataFrame(fraud_data)

# %%
fig, ax = plt.subplots(figsize=[11, 8])
b=sns.barplot(data=fraud_df,
            y='Type',
            x='Count',
            hue='Data',
            orient='h',
            ax=ax,
            palette=[REAL_COLOR, SYNTH_COLOR],
            alpha=1.0,
            )
#b.set_xscale("log")
#ax.set_xlim([0, 17])
fig.suptitle("Number of fraudulent events per transaction type in real and synthetic datasets")
ax.set_xlabel("Number of events")
ax.set_ylabel("Transaction type")
plt.legend(loc='lower right')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Unauthorized overdraft**

# %%
original_over = original[original.isUnauthorizedOverdraft == 1].action.value_counts()
synth_over = original[original.isUnauthorizedOverdraft==1].action.value_counts()

over_data = {
    'Data': len(original_over) * ['Original'] + len(synth_over) * ['Synthetic'],
    'Type': original_over.index.tolist() + synth_over.index.tolist(),
    'Count': list(original_over.values) + list(synth_over.values)
}
over_df = pd.DataFrame(over_data)

# %%
fig, ax = plt.subplots(figsize=[11, 8])
b=sns.barplot(data=over_df,
            y='Type',
            x='Count',
            hue='Data',
            orient='h',
            ax=ax,
            palette=[REAL_COLOR, SYNTH_COLOR],
            alpha=1.0,
            )
b.set_xscale("log")
fig.suptitle("Number of overdraft events per transaction type in real and synthetic datasets")
ax.set_xlabel("Number of events (logarithmic scale)")
ax.set_ylabel("Transaction type")
plt.tight_layout()
plt.show()

# %% [markdown]
# **Distribution of transactions' amounts**

# %%
fig, ax = plt.subplots(figsize=(25, 10))
sns.histplot(data=original, x='amount' , color=REAL_COLOR, label='Original', bins=100, alpha=0.5, ax=ax)
sns.histplot(data=full_synth, x='amount' , color=SYNTH_COLOR, label='Synthetic', bins=100, alpha=0.5, ax=ax)
fig.suptitle("Distribution of transaction amounts for real and synthetic data")
ax.set_xlabel("Amount (binned")
ax.set_ylabel("Count (logarithmic scale)")
ax.set_yscale('log')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# **Distribution of balances (origin entities)**

# %%
fig, ax = plt.subplots(figsize=(25, 10))
sns.histplot(data=original, x='newBalanceOrig' , color=REAL_COLOR, label='Original', bins=100, alpha=0.5, ax=ax)
sns.histplot(data=full_synth, x='newBalanceOrig' , color=SYNTH_COLOR, label='Synthetic', bins=100, alpha=0.5, ax=ax)
fig.suptitle("Distribution of balances from the origin entities for real and synthetic data")
ax.set_xlabel("Balance (binned")
ax.set_ylabel("Count (logarithmic scale)")
ax.set_yscale('log')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# This lighter color means overlap.

# %% [markdown]
# **Distribution of balances (destination entities)**

# %% [markdown]
# We need to separate by type of entity, as they have very different behaviours.

# %%
fig, axs = plt.subplots(3,1, figsize=(25, 30))
axs.flatten()

for idx, e in enumerate(['C', 'M', 'B']):
    ax = axs[idx]
    sns.histplot(data=original[original.nameDest.str[0] == e], x='newBalanceDest' , color=REAL_COLOR, label='Original', bins=100, alpha=0.5, ax=ax)
    sns.histplot(data=full_synth[full_synth.nameDest.str[0] == e], x='newBalanceDest' ,color=SYNTH_COLOR, label='Synthetic', bins=100, alpha=0.5, ax=ax)
    ax.set_title("Entity = {}".format(e))
    ax.set_xlabel("Balance (binned)")
    ax.set_ylabel("Count (logarithmic scale)")
    ax.set_yscale('log')

plt.legend()
fig.suptitle("Distribution of balances from the destination entities for real and synthetic data \n (Merchant, Bank, Customer entities)")
#plt.tight_layout()
plt.show()

# %% [markdown]
# Banks, as expected, always keep their balances in 0.

# %% [markdown]
# **Evolution over time of the balances of the destination entities**

# %% [markdown]
# To understand the evolution over time of the banking system we are simulating, let's now take a look at the **overall behaviour of the destination entities**. Let's analyze the cumulative sum of their balances, to try to understand if, regardless of the specific entities and transaction types, the overall mass of money in the destination end is constant:

# %%
fig, ax = plt.subplots(1,1, figsize=(25,8))
COLORS = [REAL_COLOR, SYNTH_COLOR]
LABELS = ['Original', 'Synthetic']

for idx, d in enumerate([original, full_synth]):
    cumsum = d.newBalanceDest.cumsum()
    time = d.time
    ax.plot(time, cumsum, label=LABELS[idx], color=COLORS[idx], linewidth=5)
    ax.fill_between(time, 0, cumsum, facecolor=COLORS[idx], alpha=0.5)
    del(cumsum, time)

ax.set_xlabel("Time")
ax.set_ylabel("Cumulative sum of the balances of the destination entities")
plt.legend()
plt.show()

# %% [markdown]
# Filtered for _Customers_, _Merchants_ and _Banks_ and the behaviour is exactly the same.

# %% [markdown]
# **Revalidation of business constraints**

# %% [markdown]
# We can reuse our Constraints and build a new Constraints Engine on the synthetic dataset to check if the new data is following our pre-defined business rules.

# %%
synth_engine = ConstraintEngine()
synth_engine.add_constraints([c1, c2, c3, c4])
synth_engine.validate(Dataset(full_synth))

# %%
synth_engine.summary()
# Out:
# {'rows_violation_count': 3429852,
#  'rows_violation_ratio': 0.9969369751685129,
#  'violation_per_constraint': {"Positive(columns=['amount'])": {'rows_violation_count': 3429852,
#    'rows_violation_ratio': 0.9969369751685129,
#    'validation_time': 1.06},
#   'Validate type of origin entity | axis=0': {'rows_violation_count': 0,
#    'rows_violation_ratio': 0.0,
#    'validation_time': 4.68},
#   'Validate overdraft behaviour | axis=1': {'rows_violation_count': 0,
#    'rows_violation_ratio': 0.0,
#    'validation_time': 49.28},
#   'Balances updates coherence | axis=1': {'rows_violation_count': 0,
#    'rows_violation_ratio': 0.0,
#    'validation_time': 226.7}}}

# %% [markdown]
# ## Wrap-up

# %% [markdown]
# _For optimal results, synthesizing data must be a balancing act between leveraging data-driven state-of-the-art algorithms and infusing the process with domain-specific knowledge. YData recognizes that and builds its entire SDK so that it's possible to get the best of both worlds._
