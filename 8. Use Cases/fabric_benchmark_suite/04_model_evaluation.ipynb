# %% [markdown]
# # Install requirements

# %%
# %%capture
# !pip install sdmetrics
# !pip install sdv
# Out:
# Requirement already satisfied: scikit-learn==1.1 in /opt/conda/lib/python3.8/site-packages (1.1.0)
# Requirement already satisfied: joblib>=1.0.0 in /opt/conda/lib/python3.8/site-packages (from scikit-learn==1.1) (1.2.0)
# Requirement already satisfied: numpy>=1.17.3 in /opt/conda/lib/python3.8/site-packages (from scikit-learn==1.1) (1.21.2)
# Requirement already satisfied: scipy>=1.3.2 in /opt/conda/lib/python3.8/site-packages (from scikit-learn==1.1) (1.6.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.8/site-packages (from scikit-learn==1.1) (3.1.0)
# Requirement already satisfied: sdmetrics in /opt/conda/lib/python3.8/site-packages (0.7.0)
# Requirement already satisfied: scikit-learn<2,>=0.24 in /opt/conda/lib/python3.8/site-packages (from sdmetrics) (1.1.0)
# Requirement already satisfied: pandas<2,>=1.1.3 in /opt/conda/lib/python3.8/site-packages (from sdmetrics) (1.2.3)
# Requirement already satisfied: scipy<2,>=1.5.4 in /opt/conda/lib/python3.8/site-packages (from sdmetrics) (1.6.0)
# Requirement already satisfied: numpy<2,>=1.20.0 in /opt/conda/lib/python3.8/site-packages (from sdmetrics) (1.21.2)
# Requirement already satisfied: torch<2,>=1.8.0 in /opt/conda/lib/python3.8/site-packages (from sdmetrics) (1.9.0+cpu)
# Requirement already satisfied: copulas<0.8,>=0.7.0 in /opt/conda/lib/python3.8/site-packages (from sdmetrics) (0.7.0)
# Requirement already satisfied: tqdm<5,>=4.15 in /opt/conda/lib/python3.8/site-packages (from sdmetrics) (4.64.1)
# Requirement already satisfied: plotly<6,>=5.10.0 in /opt/conda/lib/python3.8/site-packages (from sdmetrics) (5.11.0)
# Requirement already satisfied: matplotlib<4,>=3.4.0 in /opt/conda/lib/python3.8/site-packages (from copulas<0.8,>=0.7.0->sdmetrics) (3.5.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.8/site-packages (from pandas<2,>=1.1.3->sdmetrics) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.8/site-packages (from pandas<2,>=1.1.3->sdmetrics) (2022.6)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.8/site-packages (from plotly<6,>=5.10.0->sdmetrics) (8.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.8/site-packages (from scikit-learn<2,>=0.24->sdmetrics) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in /opt/conda/lib/python3.8/site-packages (from scikit-learn<2,>=0.24->sdmetrics) (1.2.0)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.8/site-packages (from torch<2,>=1.8.0->sdmetrics) (4.4.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.8/site-packages (from matplotlib<4,>=3.4.0->copulas<0.8,>=0.7.0->sdmetrics) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.8/site-packages (from matplotlib<4,>=3.4.0->copulas<0.8,>=0.7.0->sdmetrics) (4.38.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.8/site-packages (from matplotlib<4,>=3.4.0->copulas<0.8,>=0.7.0->sdmetrics) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.8/site-packages (from matplotlib<4,>=3.4.0->copulas<0.8,>=0.7.0->sdmetrics) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.8/site-packages (from matplotlib<4,>=3.4.0->copulas<0.8,>=0.7.0->sdmetrics) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.8/site-packages (from matplotlib<4,>=3.4.0->copulas<0.8,>=0.7.0->sdmetrics) (9.3.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas<2,>=1.1.3->sdmetrics) (1.16.0)
# Requirement already satisfied: sdv in /opt/conda/lib/python3.8/site-packages (0.17.1)
# Requirement already satisfied: deepecho<0.4,>=0.3.0.post1 in /opt/conda/lib/python3.8/site-packages (from sdv) (0.3.0.post1)
# Requirement already satisfied: pandas<2,>=1.1.3 in /opt/conda/lib/python3.8/site-packages (from sdv) (1.2.3)
# Requirement already satisfied: ctgan<0.6,>=0.5.2 in /opt/conda/lib/python3.8/site-packages (from sdv) (0.5.2)
# Requirement already satisfied: rdt<1.3.0,>=1.2.0 in /opt/conda/lib/python3.8/site-packages (from sdv) (1.2.1)
# Requirement already satisfied: copulas<0.8,>=0.7.0 in /opt/conda/lib/python3.8/site-packages (from sdv) (0.7.0)
# Requirement already satisfied: Faker<15,>=10 in /opt/conda/lib/python3.8/site-packages (from sdv) (14.2.1)
# Requirement already satisfied: graphviz<1,>=0.13.2 in /opt/conda/lib/python3.8/site-packages (from sdv) (0.20.1)
# Requirement already satisfied: cloudpickle<3.0,>=2.1.0 in /opt/conda/lib/python3.8/site-packages (from sdv) (2.2.0)
# Requirement already satisfied: numpy<2,>=1.20.0 in /opt/conda/lib/python3.8/site-packages (from sdv) (1.21.2)
# Requirement already satisfied: sdmetrics<0.8,>=0.7.0.dev0 in /opt/conda/lib/python3.8/site-packages (from sdv) (0.7.0)
# Requirement already satisfied: tqdm<5,>=4.15 in /opt/conda/lib/python3.8/site-packages (from sdv) (4.64.1)
# Requirement already satisfied: matplotlib<4,>=3.4.0 in /opt/conda/lib/python3.8/site-packages (from copulas<0.8,>=0.7.0->sdv) (3.5.3)
# Requirement already satisfied: scipy<2,>=1.5.4 in /opt/conda/lib/python3.8/site-packages (from copulas<0.8,>=0.7.0->sdv) (1.6.0)
# Requirement already satisfied: packaging<22,>=20 in /opt/conda/lib/python3.8/site-packages (from ctgan<0.6,>=0.5.2->sdv) (21.3)
# Requirement already satisfied: torchvision<1,>=0.9.0 in /opt/conda/lib/python3.8/site-packages (from ctgan<0.6,>=0.5.2->sdv) (0.10.0+cpu)
# Requirement already satisfied: scikit-learn<2,>=0.24 in /opt/conda/lib/python3.8/site-packages (from ctgan<0.6,>=0.5.2->sdv) (1.1.0)
# Requirement already satisfied: torch<2,>=1.8.0 in /opt/conda/lib/python3.8/site-packages (from ctgan<0.6,>=0.5.2->sdv) (1.9.0+cpu)
# Requirement already satisfied: python-dateutil>=2.4 in /opt/conda/lib/python3.8/site-packages (from Faker<15,>=10->sdv) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.8/site-packages (from pandas<2,>=1.1.3->sdv) (2022.6)
# Requirement already satisfied: pyyaml<6,>=5.4.1 in /opt/conda/lib/python3.8/site-packages (from rdt<1.3.0,>=1.2.0->sdv) (5.4.1)
# Requirement already satisfied: psutil<6,>=5.7 in /opt/conda/lib/python3.8/site-packages (from rdt<1.3.0,>=1.2.0->sdv) (5.9.4)
# Requirement already satisfied: plotly<6,>=5.10.0 in /opt/conda/lib/python3.8/site-packages (from sdmetrics<0.8,>=0.7.0.dev0->sdv) (5.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.8/site-packages (from matplotlib<4,>=3.4.0->copulas<0.8,>=0.7.0->sdv) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.8/site-packages (from matplotlib<4,>=3.4.0->copulas<0.8,>=0.7.0->sdv) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.8/site-packages (from matplotlib<4,>=3.4.0->copulas<0.8,>=0.7.0->sdv) (9.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.8/site-packages (from matplotlib<4,>=3.4.0->copulas<0.8,>=0.7.0->sdv) (4.38.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.8/site-packages (from matplotlib<4,>=3.4.0->copulas<0.8,>=0.7.0->sdv) (0.11.0)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.8/site-packages (from plotly<6,>=5.10.0->sdmetrics<0.8,>=0.7.0.dev0->sdv) (8.1.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.8/site-packages (from python-dateutil>=2.4->Faker<15,>=10->sdv) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.8/site-packages (from scikit-learn<2,>=0.24->ctgan<0.6,>=0.5.2->sdv) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in /opt/conda/lib/python3.8/site-packages (from scikit-learn<2,>=0.24->ctgan<0.6,>=0.5.2->sdv) (1.2.0)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.8/site-packages (from torch<2,>=1.8.0->ctgan<0.6,>=0.5.2->sdv) (4.4.0)

# %% [markdown]
# # Model Evaluation

# %%
from typing import Dict
from sdmetrics.reports.single_table import QualityReport
from pandas import read_csv
import time
import os
from pathlib import Path
import json

from common.config import *
from common.utils import update_json_file, ndd, ndd_to_dict, load_dataframe, get_model_class

def compute_model_eval(model_name: str, dataset_name: str) -> Dict:
    evals = ndd()

    report_path = Path(ANALYSIS_REPORTS_PATH) / f'sdv_report_{model_name}_{dataset_name}.pkl'
    if not os.path.isfile(report_path):
        metadata_path = Path(DATASET_PATH) / f'{dataset_name}_all.metadata.sdv.json'
        f = open(metadata_path)
        sdv_metadata = json.load(f)
        
        from sdv.metadata.table import Table

        sdv_metadata = Table.from_dict(sdv_metadata)

        dataset_df = load_dataframe(dataset_name)
        sample_df = read_csv(Path(SAMPLES_PATH) / f'{model_name}_{dataset_name}_sample.csv')

        report = QualityReport()
        report.generate(dataset_df, sample_df, sdv_metadata.to_dict())
        report.save(report_path)
    else:
        print('  Load the report as it already exists...')
        report = QualityReport.load(report_path)

    evals['sdv']['score'] = report.get_score()
    evals['sdv']['properties'] = {e["Property"]:e["Score"] for e in report.get_properties().to_dict(orient='records')}

    return ndd_to_dict(evals)

def evaluate_holdout(dataset_name):
    evals = ndd()

    report_path = Path(ANALYSIS_REPORTS_PATH) / f'sdv_report_holdout_{dataset_name}.pkl'
    if not os.path.isfile(report_path):
        dataset_df = load_dataframe(dataset_name)
        holdout_df = read_csv(Path(DATASET_PATH) / f'{dataset_name}_holdout.csv')
        metadata_path = Path(DATASET_PATH) / f'{dataset_name}_all.metadata.sdv.json'
        f = open(metadata_path)
        sdv_metadata = json.load(f)
        
        from sdv.metadata.table import Table

        sdv_metadata = Table.from_dict(sdv_metadata)

        evals = ndd()
        report = QualityReport()
        report.generate(dataset_df, holdout_df, sdv_metadata.to_dict())
        report.save(report_path)
    else:
        print('  Load the report as it already exists...')
        report = QualityReport.load(report_path)

    evals['sdv']['score'] = report.get_score()
    evals['sdv']['properties'] = {e["Property"]:e["Score"] for e in report.get_properties().to_dict(orient='records')}
    return evals

def compute_models_eval():
    datasets_config = get_datsets_config()
    models_config = get_models_config()

    evals = ndd()
    for dataset_name in datasets_config.keys():
        print(f'# Holdout on {dataset_name}')
        evals[dataset_name]['holdout'] = evaluate_holdout(dataset_name)
        for model_name in models_config.keys():
            print(f'# Model {model_name} on {dataset_name}')
            try:
                evals[dataset_name][model_name] = compute_model_eval(model_name, dataset_name)
            except Exception as e:
                print('Could not generate the report!')
                print(e)
    return ndd_to_dict(evals)

# %%
models_eval = compute_models_eval()
# Out:
# # Holdout on sdv.adult
#   Load the report as it already exists...
# # Model fabric.regular on sdv.adult
#   Load the report as it already exists...
# # Model sdv.tabular on sdv.adult
#   Load the report as it already exists...

# %%
from common.config import get_analysis_config
from common.utils import update_json_file

analysis_config = get_analysis_config()

path = analysis_config['output_files']['eval']
update_json_file(path, models_eval)
